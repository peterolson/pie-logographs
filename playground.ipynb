# %%
import pandas as pd

df = pd.read_excel("wiktionary_Pie.xlsx")
df
# Out:
#       headword Chinese                                           meanings  \
# 0          *nu       且                now; well (as an interjection); and
# 1       *pótis       主                             master, ruler; husband
# 2          *ís       之  the (just named, anaphoric). This demonstrativ...
# 3       *h₁es-       也                                              to be
# 4        *mon-       人                                   man, human being
# ...        ...     ...                                                ...
# 1329      *yós     NaN                        that, who, which (relative)
# 1330      *yū́     NaN                                       you (plural)
# 1331    *yugóm     NaN                                               yoke
# 1332   *yugtós     NaN                                      yoked, joined
# 1333  *yunégti     NaN                                      to be joining
#
#        pos                                         source_url
# 0      adv  https://en.wiktionary.org/wiki/Reconstruction:...
# 1     noun  https://en.wiktionary.org/wiki/Reconstruction:...
# 2     pron  https://en.wiktionary.org/wiki/Reconstruction:...
# 3     root  https://en.wiktionary.org/wiki/Reconstruction:...
# 4     root  https://en.wiktionary.org/wiki/Reconstruction:...
# ...    ...                                                ...
# 1329  pron  https://en.wiktionary.org/wiki/Reconstruction:...
# 1330  pron  https://en.wiktionary.org/wiki/Reconstruction:...
# 1331  noun  https://en.wiktionary.org/wiki/Reconstruction:...
# 1332   adj  https://en.wiktionary.org/wiki/Reconstruction:...
# 1333  verb  https://en.wiktionary.org/wiki/Reconstruction:...
#
# [1334 rows x 5 columns]

# %%
df.rename(columns={"headword": "PIE", "Chinese":"char", "source_url": "references"}, inplace=True)
df
# Out:
#            PIE char                                           meanings   pos  \
# 0          *nu    且                now; well (as an interjection); and   adv
# 1       *pótis    主                             master, ruler; husband  noun
# 2          *ís    之  the (just named, anaphoric). This demonstrativ...  pron
# 3       *h₁es-    也                                              to be  root
# 4        *mon-    人                                   man, human being  root
# ...        ...  ...                                                ...   ...
# 1329      *yós  NaN                        that, who, which (relative)  pron
# 1330      *yū́  NaN                                       you (plural)  pron
# 1331    *yugóm  NaN                                               yoke  noun
# 1332   *yugtós  NaN                                      yoked, joined   adj
# 1333  *yunégti  NaN                                      to be joining  verb
#
#                                              references
# 0     https://en.wiktionary.org/wiki/Reconstruction:...
# 1     https://en.wiktionary.org/wiki/Reconstruction:...
# 2     https://en.wiktionary.org/wiki/Reconstruction:...
# 3     https://en.wiktionary.org/wiki/Reconstruction:...
# 4     https://en.wiktionary.org/wiki/Reconstruction:...
# ...                                                 ...
# 1329  https://en.wiktionary.org/wiki/Reconstruction:...
# 1330  https://en.wiktionary.org/wiki/Reconstruction:...
# 1331  https://en.wiktionary.org/wiki/Reconstruction:...
# 1332  https://en.wiktionary.org/wiki/Reconstruction:...
# 1333  https://en.wiktionary.org/wiki/Reconstruction:...
#
# [1334 rows x 5 columns]

# %%
df = df.fillna("")

records = df.to_dict(orient="records")
for record in records:
    record["references"] = [record["references"]]
records
# Out:
# [{'PIE': '*nu',
#   'char': '且',
#   'details': 'now; well (as an interjection); and',
#   'pos': 'adv',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/nu']},
#  {'PIE': '*pótis',
#   'char': '主',
#   'details': 'master, ruler; husband',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%B3tis']},
#  {'PIE': '*ís',
#   'char': '之',
#   'details': 'the (just named, anaphoric). This demonstrative was used instead of a third-person pronoun.',
#   'pos': 'pron',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C3%ADs']},
#  {'PIE': '*h₁es-',
#   'char': '也',
#   'details': 'to be',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%81es-']},
#  {'PIE': '*mon-',
#   'char': '人',
#   'details': 'man, human being',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/mon-']},
#  {'PIE': '*ḱlew-',
#   'char': '令',
#   'details': 'to hear',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1lew-']},
#  {'PIE': '*ḱlews-',
#   'char': '令',
#   'details': 'to hear',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1lews-']},
#  {'PIE': '*ḱléwt',
#   'char': '令',
#   'details': 'to hear',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1l%C3%A9wt']},
#  {'PIE': '*ḱl̥néwti',
#   'char': '令',
#   'details': 'to be listening',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1l%CC%A5n%C3%A9wti']},
#  {'PIE': '*wéy',
#   'char': '余',
#   'details': 'we (more than two)',
#   'pos': 'pron',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/w%C3%A9y']},
#  {'PIE': '*(h₂)népōts',
#   'char': '后',
#   'details': 'grandson; descendant; (possibly) nephew',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9p%C5%8Dts']},
#  {'PIE': '*h₂egʰ-',
#   'char': '凶',
#   'details': 'to be upset, afraid',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82eg%CA%B0-']},
#  {'PIE': '*h₃ep-',
#   'char': '力',
#   'details': 'to work, toil, make; ability, force',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83ep-']},
#  {'PIE': '*séh₂ls',
#   'char': '卤',
#   'details': 'salt',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/s%C3%A9h%E2%82%82ls']},
#  {'PIE': '*ǵónu',
#   'char': '卩',
#   'details': 'knee',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%C3%B3nu']},
#  {'PIE': '*teh₂g-',
#   'char': '又',
#   'details': '; to touch; ; to grasp, take with the hand',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/teh%E2%82%82g-']},
#  {'PIE': '*ten-',
#   'char': '及',
#   'details': 'to stretch, to extend Synonym: *temp-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/ten-']},
#  {'PIE': '*tend-',
#   'char': '及',
#   'details': '; to stretch, to extend',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/tend-']},
#  {'PIE': '*h₁óh₃s',
#   'char': '口',
#   'details': 'mouth',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%81%C3%B3h%E2%82%83s']},
#  {'PIE': '*-kʷe',
#   'char': '合',
#   'details': 'and *h₂ówis *h₁éḱwōskʷe ― the sheep and the horses (literally, “[the] sheep [the] horses-and”) Antonym: *-wē (“or”); Forms distributives from interrogatives.',
#   'pos': 'conj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/-k%CA%B7e']},
#  {'PIE': '*sewh₁-',
#   'char': '育',
#   'details': 'to bear (a child); to give birth',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sewH-']},
#  {'PIE': '*semh₂-',
#   'char': '夏',
#   'details': 'summer (season); year',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/semh%E2%82%82-']},
#  {'PIE': '*méǵh₂s',
#   'char': '大',
#   'details': 'big, great',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/m%C3%A9%C7%B5h%E2%82%82s']},
#  {'PIE': '*méǵh₂yōs',
#   'char': '大',
#   'details': 'bigger, greater',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/m%C3%A9%C7%B5h%E2%82%82y%C5%8Ds']},
#  {'PIE': '*dyew-',
#   'char': '天',
#   'details': 'to be bright, to shine; sky, heaven',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/dyew-']},
#  {'PIE': '*wiHrós',
#   'char': '夫',
#   'details': 'man; husband; warrior, hero',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/wiHr%C3%B3s']},
#  {'PIE': '*bʰegʷ-',
#   'char': '奔',
#   'details': 'to flee Synonym: *bʰewg-; to run',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eg%CA%B7-']},
#  {'PIE': '*bʰewg-',
#   'char': '奔',
#   'details': '; to flee Synonym: *bʰegʷ-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ewg-']},
#  {'PIE': '*suh₁nús',
#   'char': '后',
#   'details': 'son',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/suHn%C3%Bas']},
#  {'PIE': '*sed-',
#   'char': '尸',
#   'details': 'to sit',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sed-']},
#  {'PIE': '*sédt',
#   'char': '尸',
#   'details': 'to sit down',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/s%C3%A9dt']},
#  {'PIE': '*sedtós',
#   'char': '尸',
#   'details': 'seated',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sedt%C3%B3s']},
#  {'PIE': '*sédyeti',
#   'char': '尸',
#   'details': 'to be sitting',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/s%C3%A9dyeti']},
#  {'PIE': '*múHtrom',
#   'char': '尿',
#   'details': 'excrement, urine; filth, sediment',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/m%C3%BAHtrom']},
#  {'PIE': '*swé',
#   'char': '己',
#   'details': 'self (reflexive pronoun)',
#   'pos': 'pron',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sw%C3%A9']},
#  {'PIE': '*ḱḗr',
#   'char': '心',
#   'details': 'heart',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1%E1%B8%97r']},
#  {'PIE': '*ḱerd-',
#   'char': '心',
#   'details': 'heart',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1erd-']},
#  {'PIE': '*éǵh₂',
#   'char': '我',
#   'details': 'I (first-person pronoun)',
#   'pos': 'pron',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C3%A9%C7%B5h%E2%82%82']},
#  {'PIE': '*eǵh₂óm',
#   'char': '我',
#   'details': 'Alternative form of *éǵh₂',
#   'pos': 'pron',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/e%C7%B5h%E2%82%82%C3%B3m']},
#  {'PIE': '*ǵʰes-',
#   'char': '手',
#   'details': 'hand; to take, give in exchange',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%CA%B0es-']},
#  {'PIE': '*ǵʰésōr',
#   'char': '手',
#   'details': 'hand',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%CA%B0%C3%A9s%C5%8Dr']},
#  {'PIE': '*h₂eḱ-',
#   'char': '才',
#   'details': 'sharp',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82e%E1%B8%B1-']},
#  {'PIE': '*sóh₂wl̥',
#   'char': '日',
#   'details': 'sun',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/s%C3%B3h%E2%82%82wl%CC%A5']},
#  {'PIE': '*gʷʰer-',
#   'char': '昜',
#   'details': 'warm, hot',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/g%CA%B7%CA%B0er-']},
#  {'PIE': '*gʷʰéros',
#   'char': '昜',
#   'details': 'heat; warm weather',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/g%CA%B7%CA%B0%C3%A9ros']},
#  {'PIE': '*gʷʰoréyeti',
#   'char': '昜',
#   'details': 'to heat',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/g%CA%B7%CA%B0or%C3%A9yeti']},
#  {'PIE': '*wekʷ-',
#   'char': '曰',
#   'details': 'to speak, to sound out',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/wek%CA%B7-']},
#  {'PIE': '*wéwket',
#   'char': '曰',
#   'details': 'to say',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/w%C3%A9wket']},
#  {'PIE': '*ǵʰeh₂-',
#   'char': '欠',
#   'details': 'to yawn, gape',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%CA%B0eh%E2%82%82-']},
#  {'PIE': '*pṓds',
#   'char': '止',
#   'details': 'foot',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%E1%B9%93ds']},
#  {'PIE': '*só',
#   'char': '此',
#   'details': 'this; that',
#   'pos': 'pron',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/s%C3%B3']},
#  {'PIE': '*méh₂tēr',
#   'char': '母',
#   'details': 'mother Synonym: *ǵénh₁trih₂ Hypernym: *ǵénh₁tōr',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/m%C3%A9h%E2%82%82t%C4%93r']},
#  {'PIE': '*h₂welh₁-',
#   'char': '毛',
#   'details': '; to rule; strong, powerful; hair; wool',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82welh%E2%82%81-']},
#  {'PIE': '*wed-',
#   'char': '水',
#   'details': 'water',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/wed-']},
#  {'PIE': '*wódr̥',
#   'char': '水',
#   'details': 'water',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/w%C3%B3dr%CC%A5']},
#  {'PIE': '*yúHs',
#   'char': '湯',
#   'details': 'soup, broth; fermented product; leaven',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/y%C3%BAHs']},
#  {'PIE': '*h₁n̥gʷnís',
#   'char': '火',
#   'details': 'fire Synonyms: *h₂eh₁ter-, *péh₂wr̥',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%81n%CC%A5g%CA%B7n%C3%ADs']},
#  {'PIE': '*péh₂wr̥',
#   'char': '火',
#   'details': 'fire Synonyms: *h₁n̥gʷnís, *h₂eh₁ter-; spelt (grain)[2][3]',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9h%E2%82%82wr%CC%A5']},
#  {'PIE': '*dʰegʷʰ-',
#   'char': '灷',
#   'details': 'to burn; warm, hot',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/d%CA%B0eg%CA%B7%CA%B0-']},
#  {'PIE': '*dʰégʷʰeti',
#   'char': '灷',
#   'details': 'to burn, to be burning',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/d%CA%B0%C3%A9g%CA%B7%CA%B0eti']},
#  {'PIE': '*h₁engʷ-',
#   'char': '炎',
#   'details': 'to burn; fire',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%81eng%CA%B7-']},
#  {'PIE': '*tek-',
#   'char': '爪',
#   'details': '; to take by the hand; to receive, obtain',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/tek-']},
#  {'PIE': '*h₂éǵeti',
#   'char': '爰',
#   'details': 'to be driving',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82%C3%A9%C7%B5eti']},
#  {'PIE': '*dʰeh₁-',
#   'char': '爲',
#   'details': 'to do; to put, place',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/d%CA%B0eh%E2%82%81-']},
#  {'PIE': '*ǵenh₁-',
#   'char': '生',
#   'details': 'to produce, to beget, to give birth',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5enh%E2%82%81-']},
#  {'PIE': '*ǵénh₁mn̥',
#   'char': '生',
#   'details': 'offspring, seed',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%C3%A9nh%E2%82%81mn%CC%A5']},
#  {'PIE': '*ǵénh₁os',
#   'char': '生',
#   'details': 'race, lineage',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%C3%A9nh%E2%82%81os']},
#  {'PIE': '*ǵénh₁tis',
#   'char': '生',
#   'details': 'birth, production',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%C3%A9nh%E2%82%81tis']},
#  {'PIE': '*ǵénh₁tōr',
#   'char': '生',
#   'details': 'one who begets, produces; parent',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%C3%A9nh%E2%82%81t%C5%8Dr']},
#  {'PIE': '*ǵénh₁trih₂',
#   'char': '生',
#   'details': 'mother',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C7%B5%C3%A9nh%E2%82%81trih%E2%82%82']},
#  {'PIE': '*h₂éǵros',
#   'char': '田',
#   'details': 'field, pasturage',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82%C3%A9%C7%B5ros']},
#  {'PIE': '*h₂éǵr̥yos',
#   'char': '田',
#   'details': 'campestral, field (attributive), of or relating to fields',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82%C3%A9%C7%B5r%CC%A5yos']},
#  {'PIE': '*h₃ekʷ-',
#   'char': '目',
#   'details': 'to see; eye',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83ek%CA%B7-']},
#  {'PIE': '*h₃reǵ-',
#   'char': '直',
#   'details': 'to straighten; to righten',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83re%C7%B5-']},
#  {'PIE': '*h₃réǵeti',
#   'char': '直',
#   'details': 'to be straightening, to be setting upright',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83r%C3%A9%C7%B5eti']},
#  {'PIE': '*h₃rḗǵnih₂',
#   'char': '直',
#   'details': 'queen',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83r%E1%B8%97%C7%B5nih%E2%82%82']},
#  {'PIE': '*h₃rḗǵs',
#   'char': '直',
#   'details': 'king, ruler',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83r%E1%B8%97%C7%B5s']},
#  {'PIE': '*h₃reǵtós',
#   'char': '直',
#   'details': 'straightened, right, upright',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%83re%C7%B5t%C3%B3s']},
#  {'PIE': '*speḱ-',
#   'char': '看',
#   'details': 'to see, to look, to observe',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/spe%E1%B8%B1-']},
#  {'PIE': '*spéḱs',
#   'char': '看',
#   'details': 'watcher; spy',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sp%C3%A9%E1%B8%B1s']},
#  {'PIE': '*spéḱyeti',
#   'char': '看',
#   'details': 'to be looking at, to keep looking at',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sp%C3%A9%E1%B8%B1yeti']},
#  {'PIE': '*(H)ísus',
#   'char': '矢',
#   'details': 'arrow',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(H)%C3%ADsus']},
#  {'PIE': '*tews-',
#   'char': '穴',
#   'details': 'to be empty; to drain',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/tews-']},
#  {'PIE': '*h₂ówis',
#   'char': '羊',
#   'details': 'sheep',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82%C3%B3wis']},
#  {'PIE': '*welh₁-',
#   'char': '羨',
#   'details': 'to choose; to want',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/welh%E2%82%81-']},
#  {'PIE': '*h₂ṓws',
#   'char': '耳',
#   'details': 'ear',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%82%E1%B9%93ws']},
#  {'PIE': '*mems-',
#   'char': '肉',
#   'details': 'flesh, meat',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/mems-']},
#  {'PIE': '*mḗms',
#   'char': '肉',
#   'details': 'flesh, meat',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/m%E1%B8%97ms']},
#  {'PIE': '*wes-',
#   'char': '衣',
#   'details': ';  to dress, clothe',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/wes-']},
#  {'PIE': '*wéstis',
#   'char': '衣',
#   'details': 'the act of dressing; clothing',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/w%C3%A9stis']},
#  {'PIE': '*wéstor',
#   'char': '衣',
#   'details': 'to be wearing',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/w%C3%A9stor']},
#  {'PIE': '*derḱ-',
#   'char': '見',
#   'details': 'to see',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/der%E1%B8%B1-']},
#  {'PIE': '*h₁el-',
#   'char': '象',
#   'details': 'greyish or brownish coloration; deer, elk → elephant; various tree species with bright bark, e.g. alder, elm, fir',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%81el-']},
#  {'PIE': '*bʰer-',
#   'char': '負',
#   'details': 'to bear, carry',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0er-']},
#  {'PIE': '*bʰóros',
#   'char': '負',
#   'details': 'load, what is borne, burden',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%B3ros']},
#  {'PIE': '*ḱr̥sós',
#   'char': '車',
#   'details': 'vehicle',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1r%CC%A5s%C3%B3s']},
#  {'PIE': '*weǵʰ-',
#   'char': '輦',
#   'details': 'to bring; to transport',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/we%C7%B5%CA%B0-']},
#  {'PIE': '*gʷreh₂-',
#   'char': '重',
#   'details': 'heavy Antonym: *h₁lengʷʰ-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/g%CA%B7reh%E2%82%82-']},
#  {'PIE': '*gʷréh₂us',
#   'char': '重',
#   'details': 'heavy Antonym: *h₁léngʰus',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/g%CA%B7r%C3%A9h%E2%82%82us']},
#  {'PIE': '*ne',
#   'char': '非',
#   'details': 'not',
#   'pos': 'part',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/ne']},
#  {'PIE': '*bʰel-',
#   'char': '音',
#   'details': '; to sound; to speak, roar, bark',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0el-']},
#  {'PIE': '*ḱerh₂-',
#   'char': '頁',
#   'details': 'head, top; horn',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1erh%E2%82%82-']},
#  {'PIE': '*ḱérh₂sō',
#   'char': '頁',
#   'details': '(top of the) head Synonyms: *gʰébʰōl, *kap-; skull',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%E1%B8%B1%C3%A9rh%E2%82%82s%C5%8D']},
#  {'PIE': '*pét(h₂)eti',
#   'char': '飛',
#   'details': 'to fly',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9th%E2%82%82eti']},
#  {'PIE': '*peth₂-',
#   'char': '飛',
#   'details': 'to spread out; to fly (through the sense ‘spread one’s wings’)',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peth%E2%82%82-']},
#  {'PIE': '*h₁éḱwos',
#   'char': '馬',
#   'details': 'stallion, horse Synonyms: *ǵʰéyos, *ḱr̥sós, *márkos, *mendyos',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/h%E2%82%81%C3%A9%E1%B8%B1wos']},
#  {'PIE': '*(s)ptyew-',
#   'char': '㳄',
#   'details': 'to spit, spew, sputter',
#   'pos': 'root',
#   'references': ['https://lrc.la.utexas.edu/lex/master/1856']},
#  {'PIE': '*dʰéǵʰōm',
#   'char': '𡈼',
#   'details': 'earth; human',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/d%CA%B0%C3%A9%C7%B5%CA%B0%C5%8Dm']},
#  {'PIE': '*(H)pós',
#   'char': '',
#   'details': 'afterwards, post; by, at',
#   'pos': 'adv',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%B3s']},
#  {'PIE': '*(H)resg-',
#   'char': '',
#   'details': 'to weave, knit',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(H)resg-']},
#  {'PIE': '*(H)rewH-',
#   'char': '',
#   'details': 'to dig out, to root',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(H)rewH-']},
#  {'PIE': '*(H)yeh₁-',
#   'char': '',
#   'details': 'to throw',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(H)yeh%E2%82%81-']},
#  {'PIE': '*(h₁)sewyós',
#   'char': '',
#   'details': 'left, left-hand',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/sewy%C3%B3s']},
#  {'PIE': '*(me)mógʰe',
#   'char': '',
#   'details': 'to have power, to be able to',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(me)m%C3%B3g%CA%B0e']},
#  {'PIE': '*(s)gʷes-',
#   'char': '',
#   'details': 'to extinguish',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)g%CA%B7es-']},
#  {'PIE': '*(s)h₁es-',
#   'char': '',
#   'details': 'harvest, crop, fruit',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)h%E2%82%81es-']},
#  {'PIE': '*(s)ḱeh₁w-',
#   'char': '',
#   'details': 'cold, rainy; north',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)%E1%B8%B1eh%E2%82%81w-']},
#  {'PIE': '*(s)ḱeh₁y-',
#   'char': '',
#   'details': 'to shine, shimmer',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)%E1%B8%B1eh%E2%82%81y-']},
#  {'PIE': '*(s)ḱeh₃-',
#   'char': '',
#   'details': 'darkness, shadow',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)%E1%B8%B1eh%E2%82%83-']},
#  {'PIE': '*(s)ḱeh₃ih₂',
#   'char': '',
#   'details': 'shadow, shade',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)%E1%B8%B1eh%E2%82%83ih%E2%82%82']},
#  {'PIE': '*(s)kel-',
#   'char': '',
#   'details': '; to bend, crook; bent, crooked; (bent or curved body parts) leg, heel, knee, hip',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kel-']},
#  {'PIE': '*(s)kelH-',
#   'char': '',
#   'details': 'to cut; to split, to separate',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kelH-']},
#  {'PIE': '*(s)kelh₁-',
#   'char': '',
#   'details': 'to parch, wither',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kelh%E2%82%81-']},
#  {'PIE': '*(s)keng-',
#   'char': '',
#   'details': 'to limp, hobble; to tilt, be askew',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)keng-']},
#  {'PIE': '*(s)ker-',
#   'char': '',
#   'details': ';  to cut off, sever; to separate, divide',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)ker-']},
#  {'PIE': '*(s)kerb-',
#   'char': '',
#   'details': 'sharp',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kerb-']},
#  {'PIE': '*(s)kérdʰh₁eti',
#   'char': '',
#   'details': 'to become cut, pierced',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)k%C3%A9rd%CA%B0h%E2%82%81eti']},
#  {'PIE': '*(s)kewd-',
#   'char': '',
#   'details': 'to advance, push; to drive, propel',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kewd-']},
#  {'PIE': '*(s)kewH-',
#   'char': '',
#   'details': 'to cover, conceal, hide; hide, skin',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kewH-']},
#  {'PIE': '*(s)kewh₁-',
#   'char': '',
#   'details': 'to perceive; to observe',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kewh%E2%82%81-']},
#  {'PIE': '*(s)kreybʰ-',
#   'char': '',
#   'details': 'to scratch, to tear',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)kreyb%CA%B0-']},
#  {'PIE': '*(s)kʷálos',
#   'char': '',
#   'details': 'large fish; sheatfish',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)k%CA%B7%C3%A1los']},
#  {'PIE': '*(s)leh₃y-',
#   'char': '',
#   'details': 'blueish',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)leh%E2%82%83y-']},
#  {'PIE': '*(s)mal-',
#   'char': '',
#   'details': 'small; little',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)mal-']},
#  {'PIE': '*(s)meh₂-',
#   'char': '',
#   'details': 'to beckon, signal',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)meh%E2%82%82-']},
#  {'PIE': '*(s)mel-',
#   'char': '',
#   'details': 'false, erroneous; bad, evil',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)mel-']},
#  {'PIE': '*(s)meld-',
#   'char': '',
#   'details': 'to soften, to melt',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)meld-']},
#  {'PIE': '*(s)mer-',
#   'char': '',
#   'details': 'to fall into thinking, remember, care for',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)mer-']},
#  {'PIE': '*(s)merd-',
#   'char': '',
#   'details': 'to bite, to sting',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)merd-']},
#  {'PIE': '*(s)mewk-',
#   'char': '',
#   'details': 'to let loose, release; to slip away, escape, flee',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)mewk-']},
#  {'PIE': '*(s)mey-',
#   'char': '',
#   'details': 'to laugh, to be glad',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)mey-']},
#  {'PIE': '*(s)neg-',
#   'char': '',
#   'details': 'to crawl, creeping thing',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)neg-']},
#  {'PIE': '*(s)neh₁-',
#   'char': '',
#   'details': 'to spin (thread), to sew',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)neh%E2%82%81-']},
#  {'PIE': '*(s)neh₂-',
#   'char': '',
#   'details': 'to swim; to float',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)neh%E2%82%82-']},
#  {'PIE': '*(s)néh₂ti',
#   'char': '',
#   'details': 'to swim, to be swimming',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)n%C3%A9h%E2%82%82ti']},
#  {'PIE': '*(s)néHtr̥',
#   'char': '',
#   'details': 'adder (type of snake)',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)n%C3%A9Htr%CC%A5']},
#  {'PIE': '*(s)pel-',
#   'char': '',
#   'details': 'to say aloud, recite; to publicly speak; to tell',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)pel-']},
#  {'PIE': '*(s)pend-',
#   'char': '',
#   'details': 'to stretch',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)pend-']},
#  {'PIE': '*(s)penh₁-',
#   'char': '',
#   'details': 'to twist; to weave',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)penh%E2%82%81-']},
#  {'PIE': '*(s)peyk-',
#   'char': '',
#   'details': 'name of a bird woodpecker magpie; woodpecker; magpie',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)peyk-']},
#  {'PIE': '*(s)poH(y)-',
#   'char': '',
#   'details': 'foam',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)poH(y)-']},
#  {'PIE': '*(s)rā́ps, *(s)rḗps[1]',
#   'char': '',
#   'details': 'turnip, rape, cabbage',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)r%C4%81%CC%81ps']},
#  {'PIE': '*(s)teg-',
#   'char': '',
#   'details': '; to cover',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)teg-']},
#  {'PIE': '*(s)teh₂y-',
#   'char': '',
#   'details': 'to steal',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)teh%E2%82%82y-']},
#  {'PIE': '*(s)telH-',
#   'char': '',
#   'details': 'to be silent, be still',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)telH-']},
#  {'PIE': '*(s)tenh₂-',
#   'char': '',
#   'details': 'to thunder',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)tenh%E2%82%82-']},
#  {'PIE': '*(s)tew-',
#   'char': '',
#   'details': 'to push, to hit',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)tew-']},
#  {'PIE': '*(s)tewd-',
#   'char': '',
#   'details': 'to push, to hit',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)tewd-']},
#  {'PIE': '*(s)tewg-',
#   'char': '',
#   'details': 'to push, to hit',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)tewg-']},
#  {'PIE': '*(s)tewk-',
#   'char': '',
#   'details': 'to push, press Synonyms: *bʰedʰ-, *dʰen-, *gen-, *gremH-, *pres-, *trenkʷ-; to strike, beat Synonyms: *bʰew-, *dʰen-, *kelh₂-, *kewh₂-, *kret-, *meldʰ-, *pleh₂k-, *(s)kep-; to stick into, pierce, perforate Synonyms: *bʰedʰ-, *dʰeygʷ-, *ḱelh₂-, *(s)teyg-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)tewk-']},
#  {'PIE': '*(s)tewp-',
#   'char': '',
#   'details': 'to push, to stick',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)tewp-']},
#  {'PIE': '*(s)teyg-',
#   'char': '',
#   'details': 'to be sharp; to sting',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)teyg-']},
#  {'PIE': '*(s)twerH-',
#   'char': '',
#   'details': 'to stir up, agitate; to urge on, propel',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/(s)twerH-']},
#  {'PIE': '*albʰós',
#   'char': '',
#   'details': 'white',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/alb%CA%B0%C3%B3s']},
#  {'PIE': '*átta',
#   'char': '',
#   'details': 'father Synonyms: *ph₂tḗr, *tata-',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/%C3%A1tta']},
#  {'PIE': '*bak-',
#   'char': '',
#   'details': 'peg, club',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/bak-']},
#  {'PIE': '*bel-',
#   'char': '',
#   'details': 'strength',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/bel-']},
#  {'PIE': '*bʰardʰéh₂',
#   'char': '',
#   'details': 'beard',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ard%CA%B0%C3%A9h%E2%82%82']},
#  {'PIE': '*bʰardʰéh₂tos',
#   'char': '',
#   'details': 'bearded',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ard%CA%B0%C3%A9h%E2%82%82tos']},
#  {'PIE': '*bʰebʰówdʰe',
#   'char': '',
#   'details': 'to have awareness, to be alert',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eb%CA%B0%C3%B3wd%CA%B0e']},
#  {'PIE': '*bʰebʰóydʰe',
#   'char': '',
#   'details': 'to be trusting, confident',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eb%CA%B0%C3%B3yd%CA%B0e']},
#  {'PIE': '*bʰébʰrus',
#   'char': '',
#   'details': 'beaver',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9b%CA%B0rus']},
#  {'PIE': '*bʰed-',
#   'char': '',
#   'details': 'to improve, make better',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ed-']},
#  {'PIE': '*bʰedʰh₂-',
#   'char': '',
#   'details': 'to dig, burrow; to pierce, stab',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ed%CA%B0h%E2%82%82-']},
#  {'PIE': '*bʰeg-',
#   'char': '',
#   'details': '; to break Synonyms: *bʰreg-, *bʰrew-, *bʰrews-, *Hrewp-, *kelh₂-, *h₃lem-, *lewǵ-, *(s)kep-, *weh₂ǵ-, *wreh₁ǵ-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eg-']},
#  {'PIE': '*bʰeh₁-',
#   'char': '',
#   'details': 'to foment; warm; bathe',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eh%E2%82%81-']},
#  {'PIE': '*bʰeh₂-',
#   'char': '',
#   'details': ';  to shine, glow light',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eh%E2%82%82-']},
#  {'PIE': '*bʰeh₂g-',
#   'char': '',
#   'details': 'to divide, distribute, allot',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eh%E2%82%82g-']},
#  {'PIE': '*bʰeh₂ǵʰús',
#   'char': '',
#   'details': 'arm',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eh%E2%82%82%C7%B5%CA%B0%C3%BAs']},
#  {'PIE': '*bʰeh₂ǵos',
#   'char': '',
#   'details': 'beech',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eh%E2%82%82%C7%B5os']},
#  {'PIE': '*bʰéh₂ti',
#   'char': '',
#   'details': 'to speak, to be talking',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9h%E2%82%82ti']},
#  {'PIE': '*bʰeh₃g-',
#   'char': '',
#   'details': 'to bake, to roast, to fry',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eh%E2%82%83g-']},
#  {'PIE': '*bʰelǵ-',
#   'char': '',
#   'details': 'to balk, beam',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0el%C7%B5-']},
#  {'PIE': '*bʰelǵʰ-',
#   'char': '',
#   'details': 'to swell',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0el%C7%B5%CA%B0-']},
#  {'PIE': '*bʰendʰ-',
#   'char': '',
#   'details': 'to bind; bond',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0end%CA%B0-']},
#  {'PIE': '*bʰenǵʰ-',
#   'char': '',
#   'details': 'thick',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0en%C7%B5%CA%B0-']},
#  {'PIE': '*bʰénǵʰus',
#   'char': '',
#   'details': 'dense, thick',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9n%C7%B5%CA%B0us']},
#  {'PIE': '*bʰéreti',
#   'char': '',
#   'details': '(he) is carrying',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9reti']},
#  {'PIE': '*bʰergʰ-',
#   'char': '',
#   'details': 'to safeguard, to protect; to preserve',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0erg%CA%B0-']},
#  {'PIE': '*bʰerǵʰ-',
#   'char': '',
#   'details': 'to rise up, ascend; to be elevated, up high',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0er%C7%B5%CA%B0-']},
#  {'PIE': '*bʰérǵʰonts',
#   'char': '',
#   'details': 'high',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9r%C7%B5%CA%B0onts']},
#  {'PIE': '*bʰérǵʰos',
#   'char': '',
#   'details': 'hill',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9r%C7%B5%CA%B0os']},
#  {'PIE': '*bʰérǵʰs',
#   'char': '',
#   'details': 'something high up, fortified',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9r%C7%B5%CA%B0s']},
#  {'PIE': '*bʰerH-',
#   'char': '',
#   'details': 'to pierce; to strike',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0erH-']},
#  {'PIE': '*bʰerHǵós',
#   'char': '',
#   'details': 'birch',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0erH%C7%B5%C3%B3s']},
#  {'PIE': '*bʰers-',
#   'char': '',
#   'details': 'top, tip, point',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ers-']},
#  {'PIE': '*bʰértis',
#   'char': '',
#   'details': 'the act of carrying, bearing',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9rtis']},
#  {'PIE': '*bʰewdʰ-',
#   'char': '',
#   'details': 'to be awake, be aware',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ewd%CA%B0-']},
#  {'PIE': '*bʰéwdʰeti',
#   'char': '',
#   'details': 'to be awake, aware',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9wd%CA%B0eti']},
#  {'PIE': '*bʰewgʰ-',
#   'char': '',
#   'details': 'to bend; curve, arch',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ewg%CA%B0-']},
#  {'PIE': '*bʰey-',
#   'char': '',
#   'details': 'bee',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ey-']},
#  {'PIE': '*bʰeyd-',
#   'char': '',
#   'details': 'to split',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eyd-']},
#  {'PIE': '*bʰeydʰ-',
#   'char': '',
#   'details': 'to compel, force; to trust',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eyd%CA%B0-']},
#  {'PIE': '*bʰéydʰeti',
#   'char': '',
#   'details': 'to trust',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9yd%CA%B0eti']},
#  {'PIE': '*bʰéydt',
#   'char': '',
#   'details': 'to split',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%A9ydt']},
#  {'PIE': '*bʰeyh₂-',
#   'char': '',
#   'details': 'to fear, be afraid',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0eyh%E2%82%82-']},
#  {'PIE': '*bʰidʰtós',
#   'char': '',
#   'details': 'trusted, trustworthy',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0id%CA%B0t%C3%B3s']},
#  {'PIE': '*bʰidnós',
#   'char': '',
#   'details': 'split, cloven',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0idn%C3%B3s']},
#  {'PIE': '*bʰidtós',
#   'char': '',
#   'details': 'split, cloven',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0idt%C3%B3s']},
#  {'PIE': '*bʰil-',
#   'char': '',
#   'details': 'harmonious, friendly',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0il-']},
#  {'PIE': '*bʰinédti',
#   'char': '',
#   'details': 'to be splitting',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0in%C3%A9dti']},
#  {'PIE': '*bʰleh₁-',
#   'char': '',
#   'details': '; to bleat; to cry',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0leh%E2%82%81-']},
#  {'PIE': '*bʰleh₃-',
#   'char': '',
#   'details': 'bloom, flower Synonym: *h₂endʰ-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0leh%E2%82%83-']},
#  {'PIE': '*bʰlendʰ-',
#   'char': '',
#   'details': 'to blend, to mix up; to make cloudy, opaque; blond, red-haired, ruddy (alternative/contested)',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0lend%CA%B0-']},
#  {'PIE': '*bʰlewH-',
#   'char': '',
#   'details': 'to overflow',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0lewH-']},
#  {'PIE': '*bʰleyǵ-',
#   'char': '',
#   'details': 'to shine',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ley%C7%B5-']},
#  {'PIE': '*bʰódeti',
#   'char': '',
#   'details': 'to be improving, make better',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%B3deti']},
#  {'PIE': '*bʰṓr',
#   'char': '',
#   'details': 'thief',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%E1%B9%93r']},
#  {'PIE': '*bʰoréyeti',
#   'char': '',
#   'details': 'to be carrying around; to cause to carry',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0or%C3%A9yeti']},
#  {'PIE': '*bʰosós',
#   'char': '',
#   'details': 'bare, barefoot',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0os%C3%B3s']},
#  {'PIE': '*bʰowdʰéyeti',
#   'char': '',
#   'details': 'to make aware; to awaken, arouse',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0owd%CA%B0%C3%A9yeti']},
#  {'PIE': '*bʰredʰ-',
#   'char': '',
#   'details': 'to wade',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0red%CA%B0-']},
#  {'PIE': '*bʰreg-',
#   'char': '',
#   'details': 'to break Synonyms: *bʰeg-, *Hrewp-, *kelh₂-, *lem-, *lewǵ-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0reg-']},
#  {'PIE': '*bʰréh₁wr̥',
#   'char': '',
#   'details': 'well, spring, source',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0r%C3%A9h%E2%82%81wr%CC%A5']},
#  {'PIE': '*bʰréh₂tēr',
#   'char': '',
#   'details': 'brother',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0r%C3%A9h%E2%82%82t%C4%93r']},
#  {'PIE': '*bʰreHg-',
#   'char': '',
#   'details': 'to smell, to have a strong odour',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0reHg-']},
#  {'PIE': '*bʰrekʷ-',
#   'char': '',
#   'details': 'to condense; to crowd together',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0rek%CA%B7-']},
#  {'PIE': '*bʰrem-',
#   'char': '',
#   'details': 'to make noise',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0rem-']},
#  {'PIE': '*bʰrewh₁-',
#   'char': '',
#   'details': 'to boil; to brew',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0rewh%E2%82%81-']},
#  {'PIE': '*bʰrews-',
#   'char': '',
#   'details': 'to break',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0rews-']},
#  {'PIE': '*bʰreyH-',
#   'char': '',
#   'details': 'to cut',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0reyH-']},
#  {'PIE': '*bʰruHg-',
#   'char': '',
#   'details': 'to make use of; have enjoyment of',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ruHg-']},
#  {'PIE': '*bʰudʰmḗn',
#   'char': '',
#   'details': 'bottom',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ud%CA%B0m%E1%B8%97n']},
#  {'PIE': '*bʰudʰtós',
#   'char': '',
#   'details': 'aware',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ud%CA%B0t%C3%B3s']},
#  {'PIE': '*bʰuǵ-',
#   'char': '',
#   'details': 'buck, he-goat',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0u%C7%B5-']},
#  {'PIE': '*bʰugéh₂',
#   'char': '',
#   'details': 'flight, escape',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0ug%C3%A9h%E2%82%82']},
#  {'PIE': '*bʰuH-',
#   'char': '',
#   'details': 'to be, become, grow, appear',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0uH-']},
#  {'PIE': '*bʰúHt',
#   'char': '',
#   'details': 'to become',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0%C3%BAHt']},
#  {'PIE': '*bʰuHyéti',
#   'char': '',
#   'details': 'to be becoming, to be growing, to be appearing',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/b%CA%B0uHy%C3%A9ti']},
#  {'PIE': '*dáḱru',
#   'char': '',
#   'details': 'tear (in the eyes)',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/d%C3%A1%E1%B8%B1ru']},
#  {'PIE': '*dayh₂wḗr',
#   'char': '',
#   'details': 'brother-in-law, husband’s brother',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/dayh%E2%82%82w%E1%B8%97r']},
#  {'PIE': '*de ~ *do',
#   'char': '',
#   'details': 'Emphatic or contrastive particle, and, but[2]; Postpositive demonstrative particle, towards',
#   'pos': 'part',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/de']},
#  {'PIE': '*dédeh₃ti',
#   'char': '',
#   'details': 'to be giving',
#   'pos': 'verb',
# ...
#  {'PIE': '*mr̥twós',
#   'char': '',
#   'details': 'dead',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/mr%CC%A5tw%C3%B3s']},
#  {'PIE': '*múh₂s',
#   'char': '',
#   'details': 'mouse',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/m%C3%BAh%E2%82%82s']},
#  {'PIE': '*n̥bʰrós',
#   'char': '',
#   'details': 'rain-cloud, with semantic narrowing to rain, cloud',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%CC%A5b%CA%B0r%C3%B3s']},
#  {'PIE': '*nebʰ-',
#   'char': '',
#   'details': 'to become damp, cloudy',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neb%CA%B0-']},
#  {'PIE': '*nébʰos',
#   'char': '',
#   'details': 'cloud; mist, moisture',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9b%CA%B0os']},
#  {'PIE': '*negʷ-',
#   'char': '',
#   'details': 'bare, naked',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neg%CA%B7-']},
#  {'PIE': '*negʷʰrós',
#   'char': '',
#   'details': 'kidney',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neg%CA%B7%CA%B0r%C3%B3s']},
#  {'PIE': '*néh₂s',
#   'char': '',
#   'details': 'nose',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9h%E2%82%82s']},
#  {'PIE': '*néh₂us',
#   'char': '',
#   'details': 'boat',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9h%E2%82%82us']},
#  {'PIE': '*neh₂w-',
#   'char': '',
#   'details': 'to die, perish; to lack; death',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neh%E2%82%82w-']},
#  {'PIE': '*neḱ-',
#   'char': '',
#   'details': 'to perish, disappear Synonyms: *dʰgʷʰey-, *mer-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/ne%E1%B8%B1-']},
#  {'PIE': '*néḱus',
#   'char': '',
#   'details': 'dead; mortal',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9%E1%B8%B1us']},
#  {'PIE': '*nem-',
#   'char': '',
#   'details': 'to distribute; to give, to take',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/nem-']},
#  {'PIE': '*némos',
#   'char': '',
#   'details': 'bowing, bending; sacrifice, worship; place of sacrifice, clearing',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9mos']},
#  {'PIE': '*néptih₂',
#   'char': '',
#   'details': 'granddaughter; niece',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9ptih%E2%82%82']},
#  {'PIE': '*nes-',
#   'char': '',
#   'details': 'to return home (safely)',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/nes-']},
#  {'PIE': '*new-',
#   'char': '',
#   'details': '; new',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/new-']},
#  {'PIE': '*néweh₂ti',
#   'char': '',
#   'details': 'to renew',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9weh%E2%82%82ti']},
#  {'PIE': '*néwos',
#   'char': '',
#   'details': 'new',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9wos']},
#  {'PIE': '*néwoteh₂ts',
#   'char': '',
#   'details': 'newness',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9woteh%E2%82%82ts']},
#  {'PIE': '*néwyos',
#   'char': '',
#   'details': 'Alternative form of *néwos',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%A9wyos']},
#  {'PIE': '*neygʷ-',
#   'char': '',
#   'details': 'to wash',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neyg%CA%B7-']},
#  {'PIE': '*neyH-',
#   'char': '',
#   'details': 'to lead',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neyH-']},
#  {'PIE': '*neyk-',
#   'char': '',
#   'details': 'to winnow, swing grains in a mill',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/neyk-']},
#  {'PIE': '*-níd-',
#   'char': '',
#   'details': 'nit, louse egg',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/-n%C3%ADd-']},
#  {'PIE': '*nisdós',
#   'char': '',
#   'details': 'nest',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/nisd%C3%B3s']},
#  {'PIE': '*n̥mr̥tós',
#   'char': '',
#   'details': 'immortal',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%CC%A5mr%CC%A5t%C3%B3s']},
#  {'PIE': '*nókʷts',
#   'char': '',
#   'details': "night (or possibly 'evening')",
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/n%C3%B3k%CA%B7ts']},
#  {'PIE': '*oḱtódḱomt',
#   'char': '',
#   'details': 'eighty',
#   'pos': 'num',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/o%E1%B8%B1t%C3%B3d%E1%B8%B1omt']},
#  {'PIE': '*oḱtṓw',
#   'char': '',
#   'details': 'eight',
#   'pos': 'num',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/o%E1%B8%B1t%E1%B9%93w']},
#  {'PIE': '*p(t)erH-',
#   'char': '',
#   'details': 'fern',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p(t)erH-']},
#  {'PIE': '*ped-',
#   'char': '',
#   'details': 'to walk, to step; to stumble, to fall',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/ped-']},
#  {'PIE': '*peg-',
#   'char': '',
#   'details': 'breast',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peg-']},
#  {'PIE': '*peh₁-',
#   'char': '',
#   'details': 'to hate, hurt',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peh%E2%82%81-']},
#  {'PIE': '*peh₂-',
#   'char': '',
#   'details': 'to protect, to ward; to shepherd',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peh%E2%82%82-']},
#  {'PIE': '*peh₂ǵ-',
#   'char': '',
#   'details': 'to attach, fix, fasten',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peh%E2%82%82%C7%B5-']},
#  {'PIE': '*peh₂ḱ-',
#   'char': '',
#   'details': 'to join, to attach; agreement, settlement',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peh%E2%82%82%E1%B8%B1-']},
#  {'PIE': '*péh₂sti',
#   'char': '',
#   'details': 'to guard, to protect; to shepherd',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9h%E2%82%82sti']},
#  {'PIE': '*peh₂w-',
#   'char': '',
#   'details': 'few, little; smallness',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peh%E2%82%82w-']},
#  {'PIE': '*peh₃-',
#   'char': '',
#   'details': 'to drink Synonym: *h₁egʷʰ-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peh%E2%82%83-']},
#  {'PIE': '*peḱ-',
#   'char': '',
#   'details': '; to pluck (wool, hair)',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pe%E1%B8%B1-']},
#  {'PIE': '*péḱu',
#   'char': '',
#   'details': 'livestock',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9%E1%B8%B1u']},
#  {'PIE': '*pekʷ-',
#   'char': '',
#   'details': 'to cook; to ripen',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pek%CA%B7-']},
#  {'PIE': '*pékʷeti',
#   'char': '',
#   'details': 'to be cooking; to ripen',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9k%CA%B7eti']},
#  {'PIE': '*pel-',
#   'char': '',
#   'details': 'to cover, to wrap; ;  skin, hide, cloth',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pel-']},
#  {'PIE': '*pelH-',
#   'char': '',
#   'details': 'pale, gray',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pelH-']},
#  {'PIE': '*pelh₂-',
#   'char': '',
#   'details': 'to approach',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pelh%E2%82%82-']},
#  {'PIE': '*pénkʷe',
#   'char': '',
#   'details': 'five',
#   'pos': 'num',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9nk%CA%B7e']},
#  {'PIE': '*pénkʷedḱomt',
#   'char': '',
#   'details': 'fifty',
#   'pos': 'num',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9nk%CA%B7ed%E1%B8%B1omt']},
#  {'PIE': '*pent-',
#   'char': '',
#   'details': 'to pass; path',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pent-']},
#  {'PIE': '*per',
#   'char': '',
#   'details': 'around; through',
#   'pos': 'adv',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/per']},
#  {'PIE': '*per-',
#   'char': '',
#   'details': ';  before, in front; first',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/per-']},
#  {'PIE': '*perd-',
#   'char': '',
#   'details': 'to fart loudly, pass gas, break wind',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/perd-']},
#  {'PIE': '*pérdetor',
#   'char': '',
#   'details': 'to be farting',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9rdetor']},
#  {'PIE': '*perḱ-',
#   'char': '',
#   'details': 'colored; speckled',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/per%E1%B8%B1-']},
#  {'PIE': '*pérkus',
#   'char': '',
#   'details': 'oak',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9rkus']},
#  {'PIE': '*pérḱus',
#   'char': '',
#   'details': 'chest; rib',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9r%E1%B8%B1us']},
#  {'PIE': '*perkʷ-',
#   'char': '',
#   'details': 'oak',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/perk%CA%B7-']},
#  {'PIE': '*pers-',
#   'char': '',
#   'details': 'to sprinkle, to spatter',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pers-']},
#  {'PIE': '*pértus',
#   'char': '',
#   'details': 'crossing',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9rtus']},
#  {'PIE': '*péruti',
#   'char': '',
#   'details': 'last year',
#   'pos': 'adv',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9ruti']},
#  {'PIE': '*pérwr̥',
#   'char': '',
#   'details': ';  ford, crossing',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9rwr%CC%A5']},
#  {'PIE': '*pes-',
#   'char': '',
#   'details': 'penis',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pes-']},
#  {'PIE': '*pesd-',
#   'char': '',
#   'details': 'to fart softly, pass gas, break wind Synonym: *perd-',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pesd-']},
#  {'PIE': '*péth₂r̥',
#   'char': '',
#   'details': 'wing; feather',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9th%E2%82%82r%CC%A5']},
#  {'PIE': '*pewǵ-',
#   'char': '',
#   'details': 'to punch, fist-fight; to prick, poke, stab',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pew%C7%B5-']},
#  {'PIE': '*pewH-',
#   'char': '',
#   'details': 'to be clean, pure',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pewH-']},
#  {'PIE': '*pewḱ-',
#   'char': '',
#   'details': 'pine',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pew%E1%B8%B1-']},
#  {'PIE': '*peyǵ-',
#   'char': '',
#   'details': 'inactive, reluctant',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pey%C7%B5-']},
#  {'PIE': '*peyh₂-',
#   'char': '',
#   'details': 'to swell (with milk) Synonyms: *ḱewh₁-, *swelH-, *tewh₂-; to be swollen, fat',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peyh%E2%82%82-']},
#  {'PIE': '*péyh₂tu',
#   'char': '',
#   'details': 'something fattening, nourishing',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9yh%E2%82%82tu']},
#  {'PIE': '*péyh₂wr̥',
#   'char': '',
#   'details': 'fat; swelling',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9yh%E2%82%82wr%CC%A5']},
#  {'PIE': '*peyḱ-',
#   'char': '',
#   'details': '; to hew, cut out; to stitch, embroider, sting; (by extension) to paint, mark, color',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pey%E1%B8%B1-']},
#  {'PIE': '*peys-',
#   'char': '',
#   'details': 'to grind, to crush',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/peys-']},
#  {'PIE': '*péysks',
#   'char': '',
#   'details': '(West Indo-European) fish Synonym: *dʰǵʰu- (eastern dialects, not including Albanian and Indo-Iranian)',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%A9ysks']},
#  {'PIE': '*ph₂tḗr',
#   'char': '',
#   'details': 'father Synonyms: *átta, *tata-',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/ph%E2%82%82t%E1%B8%97r']},
#  {'PIE': '*píbeti',
#   'char': '',
#   'details': 'alternative reconstruction of *píph₃eti',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%ADbeti']},
#  {'PIE': '*píph₃eti',
#   'char': '',
#   'details': 'to drink, to be drinking',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%ADph%E2%82%83eti']},
#  {'PIE': '*písdeh₂',
#   'char': '',
#   'details': 'vulva',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C3%ADsdeh%E2%82%82']},
#  {'PIE': '*pī́ts',
#   'char': '',
#   'details': 'pitch, resin Synonyms: *gʷétu, *sokʷós; pine tree',
#   'pos': 'noun',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/p%C4%AB%CC%81ts']},
#  {'PIE': '*pleh₁-',
#   'char': '',
#   'details': 'to fill',
#   'pos': 'root',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pleh%E2%82%81-']},
#  {'PIE': '*pléh₁dʰh₁eti',
#   'char': '',
#   'details': 'to become full, swell; to increase, further',
#   'pos': 'verb',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pl%C3%A9h%E2%82%81d%CA%B0h%E2%82%81eti']},
#  {'PIE': '*pleh₁tós',
#   'char': '',
#   'details': 'filled, full',
#   'pos': 'adj',
#   'references': ['https://en.wiktionary.org/wiki/Reconstruction:Proto-Indo-European/pleh%E2%82%81t%C3%B3s']},
#  ...]

# %%
# create json file
import json
with open("wiktionary_Pie.json", "w", encoding="utf-8") as f:
    json.dump(records, f, ensure_ascii=False, indent=2)

# %%
# get Dong Chinese data dump
lines = []
with open(r'dictionary_char_2024-02-17.jsonl', encoding='utf-8') as f:
    lines = f.read().splitlines()

line_dicts = [json.loads(line) for line in lines]
dong_df = pd.DataFrame(line_dicts)
dong_df
# Out:
#                             _id char codepoint strokeCount  \
# 0      5f523afdde54193ed872ebbc    㠆    U+3806          15
# 1      5f523afdde54193ed872ebc0    㠊    U+380A          15
# 2      5f523afdde54193ed872ebc2    㠌    U+380C          15
# 3      5f523afdde54193ed872ebd2    㠜    U+381C          17
# 4      5f523afdde54193ed872ebe3    㠭    U+382D          12
# ...                         ...  ...       ...         ...
# 93841  5f523b00de54193ed8745396    𱂞   U+3109E          23
# 93842         CdacymTFP5X4Wiu9R    ⺮       NaN         NaN
# 93843         AwEHQD3qJqA3KjGaw  NaN       NaN         NaN
# 93844         6kbgpPMXXdLrC6sxS    ㇚       NaN         NaN
# 93845         xdFgYp7Wi8pEkgTio    𱖔   U+31594           8
#
#                           sources  \
# 0                       [unicode]
# 1                       [unicode]
# 2                       [unicode]
# 3                       [unicode]
# 4      [academia-sinica, unicode]
# ...                           ...
# 93841                   [unicode]
# 93842                         NaN
# 93843                         NaN
# 93844                         NaN
# 93845                         NaN
#
#                                                    gloss  \
# 0                                     name of a mountain
# 1                            (same as U+5D87 嶇) a rugged
# 2                                                   high
# 3      (same as 嶷) young kids smart and familiar with...
# 4                           to watch extremely carefully
# ...                                                  ...
# 93841                                                NaN
# 93842                                             bamboo
# 93843                                              birth
# 93844                          vertical line with a hook
# 93845                                          to punish
#
#                                                   images             shuowen  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4      [{'url': 'https://data.dong-chinese.com/img/si...  《說文》：“，極巧視之也。从四工。”
# ...                                                  ...                 ...
# 93841                                                NaN                 NaN
# 93842  [{'source': 'dong-chinese', 'description': '楷体...                 NaN
# 93843                                                NaN                 NaN
# 93844                                                NaN                 NaN
# 93845  [{'source': 'dong-chinese', 'description': '楷体...                 NaN
#
#                                                 comments  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      [{'source': 'academia-sinica', 'text': '段玉裁注：“...
# ...                                                  ...
# 93841                                                NaN
# 93842                                                NaN
# 93843                                                NaN
# 93844                                                NaN
# 93845                                                NaN
#
#                                                 variants  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4      [{'char': '㠭', 'parts': '工工工工', 'source': 'aca...  ...
# ...                                                  ...  ...
# 93841                                                NaN  ...
# 93842                                                NaN  ...
# 93843                                                NaN  ...
# 93844                                                NaN  ...
# 93845                                                NaN  ...
#
#       oldPronunciations       statistics originalMeaning variantOf  \
# 0                   NaN              NaN             NaN       NaN
# 1                   NaN              NaN             NaN       NaN
# 2                   NaN              NaN             NaN       NaN
# 3                   NaN              NaN             NaN       NaN
# 4                   NaN              NaN             NaN       NaN
# ...                 ...              ...             ...       ...
# 93841               NaN              NaN             NaN       NaN
# 93842               NaN  {'hskLevel': 0}             NaN         竹
# 93843               NaN              NaN             NaN       NaN
# 93844               NaN              NaN             NaN       NaN
# 93845               NaN              NaN             NaN       NaN
#
#       tradVariants pinyinFrequencies simp trad  \
# 0              NaN               NaN  NaN  NaN
# 1              NaN               NaN  NaN  NaN
# 2              NaN               NaN  NaN  NaN
# 3              NaN               NaN  NaN  NaN
# 4              NaN               NaN  NaN  NaN
# ...            ...               ...  ...  ...
# 93841          NaN               NaN  NaN  NaN
# 93842          NaN               NaN  NaN  NaN
# 93843          NaN               NaN    𠫓    𠫓
# 93844          NaN               NaN  NaN  NaN
# 93845          NaN               NaN  NaN  NaN
#
#                                                    items pinyinSearchString
# 0                                                    NaN                NaN
# 1                                                    NaN                NaN
# 2                                                    NaN                NaN
# 3                                                    NaN                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 93841                                                NaN                NaN
# 93842                                                NaN                NaN
# 93843  [{'source': 'unicode', 'pinyin': 'yù', 'simpTr...          tū tu1 tu
# 93844                                                NaN                NaN
# 93845                                                NaN                NaN
#
# [93846 rows x 27 columns]

# %%
dong_df.columns
# Out:
# Index(['_id', 'char', 'codepoint', 'strokeCount', 'sources', 'gloss', 'images',
#        'shuowen', 'comments', 'variants', 'customSources', 'hint',
#        'isVerified', 'components', 'data', 'fragments', 'simpVariants',
#        'oldPronunciations', 'statistics', 'originalMeaning', 'variantOf',
#        'tradVariants', 'pinyinFrequencies', 'simp', 'trad', 'items',
#        'pinyinSearchString'],
#       dtype='object')

# %%
dong_df = dong_df[dong_df['isVerified'] == True]
reduced = dong_df[['char', 'gloss', 'hint', 'originalMeaning']].fillna("")
# join the gloss and originalMeaning into one column, separated by a semicolon when both are present, otherwise just use the one that is present
reduced['meanings'] = reduced['gloss'] + reduced['originalMeaning'].apply(lambda x: "; " + x if x else "")
reduced['references'] = "https://www.dong-chinese.com/wiki/" + reduced['char']
reduced
# Out:
#       char                         gloss  \
# 4        㠭  to watch extremely carefully
# 46       㠯                   by means of
# 56       㠀            (same as 島) island
# 80       㡭                      continue
# 81       㡀               ragged clothing
# ...    ...                           ...
# 93643    𱂥                  the forehead
# 93807    𱁶                         swing
# 93842    ⺮                        bamboo
# 93844    ㇚     vertical line with a hook
# 93845    𱖔                     to punish
#
#                                                     hint originalMeaning  \
# 4                                        Quadruple of 工.
# 46     Variant form of 以, without the person (人) comp...           carry
# 56                                         Variant of 島.
# 80     Original form of 繼. Depicts a continuous serie...
# 81              Depicts a cloth (巾) with specks of dust.
# ...                                                  ...             ...
# 93643                                      Variant of 額.
# 93807                                      Variant of 韆.
# 93842  ⺮ is a component form of 竹, which is a pictogr...
# 93844
# 93845  Depicts a knife with tooth-shaped decorations ...
#
#                            meanings                           references
# 4      to watch extremely carefully  https://www.dong-chinese.com/wiki/㠭
# 46                by means of;carry  https://www.dong-chinese.com/wiki/㠯
# 56               (same as 島) island  https://www.dong-chinese.com/wiki/㠀
# 80                         continue  https://www.dong-chinese.com/wiki/㡭
# 81                  ragged clothing  https://www.dong-chinese.com/wiki/㡀
# ...                             ...                                  ...
# 93643                  the forehead  https://www.dong-chinese.com/wiki/𱂥
# 93807                         swing  https://www.dong-chinese.com/wiki/𱁶
# 93842                        bamboo  https://www.dong-chinese.com/wiki/⺮
# 93844     vertical line with a hook  https://www.dong-chinese.com/wiki/㇚
# 93845                     to punish  https://www.dong-chinese.com/wiki/𱖔
#
# [3313 rows x 6 columns]

# %%
reduced_dict = reduced.to_dict(orient="records")
for record in reduced_dict:
    record["references"] = [record["references"]]
reduced_dict
# Out:
# [{'char': '㠭',
#   'details': 'to watch extremely carefully --  -- Quadruple of 工.',
#   'references': ['https://www.dong-chinese.com/wiki/㠭']},
#  {'char': '㠯',
#   'details': 'by means of -- carry -- Variant form of 以, without the person (人) component. Depicts an object being carried.',
#   'references': ['https://www.dong-chinese.com/wiki/㠯']},
#  {'char': '㠀',
#   'details': '(same as 島) island --  -- Variant of 島.',
#   'references': ['https://www.dong-chinese.com/wiki/㠀']},
#  {'char': '㡭',
#   'details': 'continue --  -- Original form of 繼. Depicts a continuous series of silk threads (丝) joined together.',
#   'references': ['https://www.dong-chinese.com/wiki/㡭']},
#  {'char': '㡀',
#   'details': 'ragged clothing --  -- Depicts a cloth (巾) with specks of dust.',
#   'references': ['https://www.dong-chinese.com/wiki/㡀']},
#  {'char': '㡿',
#   'details': 'to scold -- develop new land -- Archaic variant of 斥. Phonosemantic compond: 广 represents the meaning and 乇 represents the sound. Originally a variant form of 宅, based on the original meaning "to develop new land". The 乇 component was confused with the visually similar 屰.',
#   'references': ['https://www.dong-chinese.com/wiki/㡿']},
#  {'char': '㣇',
#   'details': 'a kind of beast with long hair --  -- Pictograph of a wild animal.',
#   'references': ['https://www.dong-chinese.com/wiki/㣇']},
#  {'char': '㥯',
#   'details': 'careful --  -- Phonosemantic compound. 𤔌 represents the sound and 心 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/㥯']},
#  {'char': '㬰',
#   'details': 'basket --  -- Depicts a basket. Ancient variant of 蕢.',
#   'references': ['https://www.dong-chinese.com/wiki/㬰']},
#  {'char': '㫃',
#   'details': 'flags flying --  -- Depicts a flag on a flagpole flying in the wind.',
#   'references': ['https://www.dong-chinese.com/wiki/㫃']},
#  {'char': '㤙',
#   'details': 'grace --  -- Variant of 恩.',
#   'references': ['https://www.dong-chinese.com/wiki/㤙']},
#  {'char': '㬎',
#   'details': 'visible, bright --  -- Phonosemantic compound. 日 represents the meaning and 𢇁 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/㬎']},
#  {'char': '㪚',
#   'details': '(same as 散) to scatter --  -- Variant of 散.',
#   'references': ['https://www.dong-chinese.com/wiki/㪚']},
#  {'char': '㦰',
#   'details': 'to break off (relations) --  -- Pictograph of an agricultural tool with a blade (戈) used by two people (从).',
#   'references': ['https://www.dong-chinese.com/wiki/㦰']},
#  {'char': '㨿',
#   'details': '(a variant of 據) to receive --  -- Variant of 據.',
#   'references': ['https://www.dong-chinese.com/wiki/㨿']},
#  {'char': '㧱',
#   'details': 'take --  -- Variant of 拿.',
#   'references': ['https://www.dong-chinese.com/wiki/㧱']},
#  {'char': '㯥',
#   'details': 'pair --  -- Original form of 曹. Depicts a pair of bags or baskets.',
#   'references': ['https://www.dong-chinese.com/wiki/㯥']},
#  {'char': '䀏',
#   'details': "to move one's eyes --  -- Phonosemantic compound. 勻 represents the sound and 目 represents the meaning.",
#   'references': ['https://www.dong-chinese.com/wiki/䀏']},
#  {'char': '䇲',
#   'details': 'variant of 筴|策[cè] --  -- Variant of 筴.',
#   'references': ['https://www.dong-chinese.com/wiki/䇲']},
#  {'char': '䇂',
#   'details': 'sickle, curved blade --  -- Pictograph of a curved knife-like object.',
#   'references': ['https://www.dong-chinese.com/wiki/䇂']},
#  {'char': '䊆',
#   'details': 'rice flour --  -- Depicts rice (米) pounded into flour with a mortar (臼) and pestle.',
#   'references': ['https://www.dong-chinese.com/wiki/䊆']},
#  {'char': '䍃',
#   'details': 'vase, pitcher --  -- Phonosemantic compound. 缶 represents the meaning and ⺼ represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/䍃']},
#  {'char': '㐆',
#   'details': 'to turn the body --  -- Reversal of 身. Depicts a person with a protruding midsection.',
#   'references': ['https://www.dong-chinese.com/wiki/㐆']},
#  {'char': '㐬',
#   'details': 'birth --  -- Depicts an upside-down child (𠫓) being born with amniotic fluid (川) coming out.',
#   'references': ['https://www.dong-chinese.com/wiki/㐬']},
#  {'char': '㐅',
#   'details': 'five --  -- Archaic variant of 五 (five).',
#   'references': ['https://www.dong-chinese.com/wiki/㐅']},
#  {'char': '㐭',
#   'details': 'granary --  -- Depicts a building for storing grain.',
#   'references': ['https://www.dong-chinese.com/wiki/㐭']},
#  {'char': '㐱',
#   'details': 'thick hair --  -- Variant of 鬒. Depicts a person (人) with thick hair (彡).',
#   'references': ['https://www.dong-chinese.com/wiki/㐱']},
#  {'char': '㒸',
#   'details': 'obey --  -- 豕 represents the sound and the top two strokes disambiguate 㒸 from 豕.',
#   'references': ['https://www.dong-chinese.com/wiki/㒸']},
#  {'char': '㒼',
#   'details': 'equal --  -- Twenty (廿) and two (兩) are numbers that can be divided into two equal parts.',
#   'references': ['https://www.dong-chinese.com/wiki/㒼']},
#  {'char': '㕞',
#   'details': 'brush --  -- Variant of 刷.',
#   'references': ['https://www.dong-chinese.com/wiki/㕞']},
#  {'char': '㕁',
#   'details': '(non-classical form of 卻) still --  -- Variant of 卻.',
#   'references': ['https://www.dong-chinese.com/wiki/㕁']},
#  {'char': '㕣',
#   'details': 'a marsh at the foot of the hills --  -- Depicts a wet muddy area in a valley between two mountains.',
#   'references': ['https://www.dong-chinese.com/wiki/㕣']},
#  {'char': '㕯',
#   'details': 'slow-tongued --  -- Phonosemantic compound. 内 represents the sound and 口 represents the meaning. Variant of 訥.',
#   'references': ['https://www.dong-chinese.com/wiki/㕯']},
#  {'char': '㗊',
#   'details': 'clamour, noise --  -- Depicts four mouths (口) making noise.',
#   'references': ['https://www.dong-chinese.com/wiki/㗊']},
#  {'char': '㚔',
#   'details': 'instrument of torture used in ancient times --  -- Pictograph of shackles.',
#   'references': ['https://www.dong-chinese.com/wiki/㚔']},
#  {'char': '㝉',
#   'details': 'storage container --  -- Simplified form of 宁. Pictograph of a container for storing things.',
#   'references': ['https://www.dong-chinese.com/wiki/㝉']},
#  {'char': '㝡',
#   'details': 'most -- gather -- Old variant of 最. Phonosemantic compound. 宀 represents the meaning and 取 represents the sound. Based on the original meaning "gather". The meaning later shifted to "accumulate", "many" and "most".',
#   'references': ['https://www.dong-chinese.com/wiki/㝡']},
#  {'char': '㝵',
#   'details': 'to get --  -- Original form of 得. Depicts a hand (寸) grabbing a shell (貝), used as currency in ancient China, to convey the meaning "get".',
#   'references': ['https://www.dong-chinese.com/wiki/㝵']},
#  {'char': '㞢',
#   'details': '(ancient form of 之) to arrive at --  -- Ancient variant of 之/止, depicting a foot.',
#   'references': ['https://www.dong-chinese.com/wiki/㞢']},
#  {'char': '㟁',
#   'details': 'shore, bank --  -- Variant of 岸.',
#   'references': ['https://www.dong-chinese.com/wiki/㟁']},
#  {'char': '㳒',
#   'details': 'law --  -- Variant of 法.',
#   'references': ['https://www.dong-chinese.com/wiki/㳒']},
#  {'char': '㲋',
#   'details': 'rabbit-like animal --  -- Pictograph of a rabbit-like animal.',
#   'references': ['https://www.dong-chinese.com/wiki/㲋']},
#  {'char': '㳄',
#   'details': 'spit, saliva --  -- Depicts drops of spit (氵) coming from an open mouth (欠).',
#   'references': ['https://www.dong-chinese.com/wiki/㳄']},
#  {'char': '㱿',
#   'details': 'to strike from above -- to strike a musical instrument -- Depicts a hand holding a mallet or stick (殳) striking a musical instrument. The component originally depicting a musical instrument was later reanalyzed as a sound component (𡉉). Based on the original meaning "to strike a musical instrument". The meaning later shifted to "to strike from above".',
#   'references': ['https://www.dong-chinese.com/wiki/㱿']},
#  {'char': '㴱',
#   'details': 'deep --  -- Ancient variant of 深.',
#   'references': ['https://www.dong-chinese.com/wiki/㴱']},
#  {'char': '㽞',
#   'details': '(abbreviated form of 留) to remain --  -- Variant of 留.',
#   'references': ['https://www.dong-chinese.com/wiki/㽞']},
#  {'char': '䠶',
#   'details': 'to shoot --  -- Variant of 射.',
#   'references': ['https://www.dong-chinese.com/wiki/䠶']},
#  {'char': '䧹',
#   'details': 'eagle --  -- Pictograph of an eagle perched on a branch. Original form of 鷹.',
#   'references': ['https://www.dong-chinese.com/wiki/䧹']},
#  {'char': '䬼',
#   'details': 'satiated --  -- Phonosemantic compound. 肙 represents the sound and 飠 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/䬼']},
#  {'char': '䒑',
#   'details': 'grass --  -- Variant form of 艹.',
#   'references': ['https://www.dong-chinese.com/wiki/䒑']},
#  {'char': '䖒',
#   'details': 'earthenware with the shape of a bean --  -- Phonosemantic compound. 虍 represents the sound and 豆 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/䖒']},
#  {'char': '䖵',
#   'details': 'insects --  -- Depicts two bugs (虫)',
#   'references': ['https://www.dong-chinese.com/wiki/䖵']},
#  {'char': '䛐',
#   'details': 'words --  -- Variant of 詞 with the components arranged vertically rather than horizontally.',
#   'references': ['https://www.dong-chinese.com/wiki/䛐']},
#  {'char': '䜌',
#   'details': 'tie together --  -- Phonosemantic compound. Two threads (糸 + 糸) represent the meaning and 言 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/䜌']},
#  {'char': '偷',
#   'details': 'to steal --  -- Phonosemantic compound. 亻 represents the meaning and 俞 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/偷']},
#  {'char': '偶',
#   'details': 'pair, accidental -- idol -- Phonosemantic compound. 亻 represents the meaning and 禺 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/偶']},
#  {'char': '偉',
#   'details': 'great --  -- Phonosemantic compound. 亻 represents the meaning and 韋 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/偉']},
#  {'char': '健',
#   'details': 'healthy --  -- Phonosemantic compound. 亻 represents the meaning and 建 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/健']},
#  {'char': '偺',
#   'details': 'we --  -- Variant of 咱.',
#   'references': ['https://www.dong-chinese.com/wiki/偺']},
#  {'char': '假',
#   'details': 'falsehood --  -- Phonosemantic compound. 亻 represents the meaning and 叚 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/假']},
#  {'char': '做',
#   'details': 'work --  -- 做 originated as a variant form of 作.',
#   'references': ['https://www.dong-chinese.com/wiki/做']},
#  {'char': '停',
#   'details': 'stop --  -- Phonosemantic compound. 亻 represents the meaning and 亭 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/停']},
#  {'char': '備',
#   'details': 'prepare --  -- Depicts a person (亻) preparing a container for arrows to equip himself for battle.',
#   'references': ['https://www.dong-chinese.com/wiki/備']},
#  {'char': '傷',
#   'details': 'wound --  -- Phonosemantic compound. 亻 represents the meaning and 昜 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/傷']},
#  {'char': '傑',
#   'details': 'hero -- to be elevated -- Originally written as 桀, which depicts two feet (舛) on top of a tree (木). 亻 (person) was later added to the character as a meaning component. Based on the original meaning, "to be elevated". The meaning later shifted to "outstanding person" and "hero".',
#   'references': ['https://www.dong-chinese.com/wiki/傑']},
#  {'char': '傢',
#   'details': 'stubborn --  -- Phonosemantic compound. 亻 represents the meaning and 家 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/傢']},
#  {'char': '傲',
#   'details': 'proud --  -- Phonosemantic compound. 亻 represents the meaning and 敖 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/傲']},
#  {'char': '傳',
#   'details': 'pass on, transmit --  -- Phonosemantic compound. 亻 represents the meaning and 專 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/傳']},
#  {'char': '傾',
#   'details': 'upset --  -- Phonosemantic compound. 亻 represents the meaning and 頃 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/傾']},
#  {'char': '傅',
#   'details': 'tutor --  -- Phonosemantic compound. 亻 represents the meaning and 尃 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/傅']},
#  {'char': '傘',
#   'details': 'umbrella --  -- Pictograph of an umbrella.',
#   'references': ['https://www.dong-chinese.com/wiki/傘']},
#  {'char': '傻',
#   'details': 'foolish --  -- Depicts a person (亻) with a gap in their skull (𡕩), i.e. with no brains.',
#   'references': ['https://www.dong-chinese.com/wiki/傻']},
#  {'char': '傚',
#   'details': 'imitate --  -- Phonosemantic compound. 亻 represents the meaning and 效 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/傚']},
#  {'char': '僅',
#   'details': 'only --  -- Phonosemantic compound. 亻 represents the meaning and 堇 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/僅']},
#  {'char': '党',
#   'details': 'political party -- dark -- Simplified form of 黨.  Phonosemantic compound. 黑 represents the meaning and 尚 represents the sound. Based on the original meaning "dark". The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/党']},
#  {'char': '內',
#   'details': 'inside --  -- Depicts an entrance (入) to go inside a building (冂).',
#   'references': ['https://www.dong-chinese.com/wiki/內']},
#  {'char': '六',
#   'details': 'six --  -- Origin unclear. Various explainations include (1) possibly derives from 入 (enter), with two strokes on the bottom to distinguish it from 入 (enter) or (2) a pictograph of a hut, which is thought to be the original form of 廬. Either way, the current meaning is a phoentic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/六']},
#  {'char': '关',
#   'details': 'to close --  -- Phonosemantic compound. 門 represents the meaning and 𢇇 represents the sound.  The simplified character 关 was adapted from the cursive form of the traditional character 關. The traditional component 門 was removed for simplification.',
#   'references': ['https://www.dong-chinese.com/wiki/关']},
#  {'char': '億',
#   'details': 'hundred million -- quiet; at rest -- Phonosemantic compound. 亻 represents the meaning and 意 represents the sound. Based on the original meaning "quiet; at rest". The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/億']},
#  {'char': '先',
#   'details': 'first --  -- Depicts a person (人) stepping forward (止) leading the way.',
#   'references': ['https://www.dong-chinese.com/wiki/先']},
#  {'char': '八',
#   'details': 'eight --  -- Pictograph of two lines facing away from each other. The current meaning "eight" is a phonetic loan. The original meaning "separate" is now written as 別.',
#   'references': ['https://www.dong-chinese.com/wiki/八']},
#  {'char': '兮',
#   'details': 'exclamatory particle --  -- Origin unclear. Likely depicts two lines of air (八) blowing through branches (丂), indicating the sound of wind. Possibly similar in origin to 乎.',
#   'references': ['https://www.dong-chinese.com/wiki/兮']},
#  {'char': '僕',
#   'details': 'servant --  -- Phonosemantic compound. 亻 represents the meaning and 菐 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/僕']},
#  {'char': '儿',
#   'details': 'child --  -- Simplified form of 兒.  Variant form of 人, a pictograph of a human.',
#   'references': ['https://www.dong-chinese.com/wiki/儿']},
#  {'char': '兇',
#   'details': 'terrible, fearful --  -- Depicts a person (卩) under a trap (凶).',
#   'references': ['https://www.dong-chinese.com/wiki/兇']},
#  {'char': '免',
#   'details': '(hat), avoid -- hat -- Pictograph of a person with a hat, now written as 冕. The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/免']},
#  {'char': '兩',
#   'details': 'two --  -- Combination of two 丙 characters. 丙 also represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/兩']},
#  {'char': '像',
#   'details': 'resemble --  -- Phonosemantic compound. 亻 represents the meaning and 象 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/像']},
#  {'char': '兂',
#   'details': 'hairpin --  -- Pictograph of a woman kneeling with a hairpin in her hair. Original form of 簪. Not related to 旡 (choke on something eaten).',
#   'references': ['https://www.dong-chinese.com/wiki/兂']},
#  {'char': '兴',
#   'details': 'rise, flourish --  -- Depicts four hands (舁) working together (同) to raise something. The simplified character 兴 was adapted from the cursive form of the traditional character 興.',
#   'references': ['https://www.dong-chinese.com/wiki/兴']},
#  {'char': '優',
#   'details': 'superior --  -- Phonosemantic compound. 亻 represents the meaning and 憂 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/優']},
#  {'char': '兀',
#   'details': 'stand tall --  -- Depicts a person with the head emphasized, conveying the meaning "stand tall".',
#   'references': ['https://www.dong-chinese.com/wiki/兀']},
#  {'char': '入',
#   'details': 'enter --  -- Arrow pointing forward, representing the idea "enter".',
#   'references': ['https://www.dong-chinese.com/wiki/入']},
#  {'char': '僉',
#   'details': 'together --  -- Depicts multiple people (人) opening their mouths (口) to speak together, representing the meaning "together" or "all".',
#   'references': ['https://www.dong-chinese.com/wiki/僉']},
#  {'char': '公',
#   'details': 'public --  -- Originally a pictograph of a vessel for holding liquid, now written as 瓮, with the 瓦 (pottery) component added at the bottom. The current meaning "public" is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/公']},
#  {'char': '兰',
#   'details': 'orchid --  -- Simplified form of 蘭. Phonosemantic compound. 䒑 represents the meaning and 三 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/兰']},
#  {'char': '兆',
#   'details': 'omen -- escape -- Originally a pictograph of two people escaping a flood. Based on the original meaning "escape", now written as 逃. The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/兆']},
#  {'char': '兓',
#   'details': 'sharp --  -- Duplication of 兂 (hairpin).',
#   'references': ['https://www.dong-chinese.com/wiki/兓']},
#  {'char': '充',
#   'details': 'fill --  -- Pictograph of an adult person with a hairpin in their hair, indicating being fully grown up into adulthood. Similar in origin to 每.',
#   'references': ['https://www.dong-chinese.com/wiki/充']},
#  {'char': '光',
#   'details': 'light --  -- Pictograph of fire on top of a person.',
#   'references': ['https://www.dong-chinese.com/wiki/光']},
#  {'char': '兄',
#   'details': 'elder brother --  -- Pictograph of a mouth on top of a person, representing an older brother giving orders.',
#   'references': ['https://www.dong-chinese.com/wiki/兄']},
#  {'char': '兔',
#   'details': 'rabbit --  -- Pictograph of a rabbit.',
#   'references': ['https://www.dong-chinese.com/wiki/兔']},
#  {'char': '全',
#   'details': 'entire -- pure jade -- Depicts jade (玉) that is entirely (入) pure and flawless. Based on the original meaning "pure jade". The meaning later shifted to "complete" and "entire".',
#   'references': ['https://www.dong-chinese.com/wiki/全']},
#  {'char': '克',
#   'details': 'subdue --  -- Pictograph of a person (人) carrying a heavy weight on their back.',
#   'references': ['https://www.dong-chinese.com/wiki/克']},
#  {'char': '共',
#   'details': 'together with --  -- Pictograph of two hands holding an object together.',
#   'references': ['https://www.dong-chinese.com/wiki/共']},
#  {'char': '僱',
#   'details': 'employ --  -- Phonosemantic compound. 亻 represents the meaning and 雇 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/僱']},
#  {'char': '價',
#   'details': 'price --  -- Phonosemantic compound. 亻 represents the meaning and 賈 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/價']},
#  {'char': '允',
#   'details': 'allow, permit --  -- Phonosemantic compound. 㠯 represents the sound and 人 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/允']},
#  {'char': '元',
#   'details': 'first --  -- Pictograph of a person with a line added at the head area, representing the meaning the meaning "head" or "first".',
#   'references': ['https://www.dong-chinese.com/wiki/元']},
#  {'char': '兒',
#   'details': 'son --  -- Pictograph of a child (人) with an opening in the top of its head (囟). Represents the soft spot (fontanel) at the top of young infant heads. The 囟 component is written like 臼.',
#   'references': ['https://www.dong-chinese.com/wiki/兒']},
#  {'char': '兵',
#   'details': 'soldier --  -- Pictograph of two hands (廾) holding a weapon.',
#   'references': ['https://www.dong-chinese.com/wiki/兵']},
#  {'char': '兟',
#   'details': 'go forward --  -- Duplicate of 先 (first).',
#   'references': ['https://www.dong-chinese.com/wiki/兟']},
#  {'char': '儘',
#   'details': 'utmost --  -- Phonosemantic compound. 亻 represents the meaning and 盡 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/儘']},
#  {'char': '兌',
#   'details': "exchange -- joyous -- Depicts words (八) coming out of a person's (人) mouth (口).",
#   'references': ['https://www.dong-chinese.com/wiki/兌']},
#  {'char': '兑',
#   'details': "exchange -- joyous -- Simplified form of 兌.  Depicts words (八) coming out of a person's (人) mouth (口).",
#   'references': ['https://www.dong-chinese.com/wiki/兑']},
#  {'char': '冂',
#   'details': 'large room --  -- Pictograph of a large room. Original form of 堂.',
#   'references': ['https://www.dong-chinese.com/wiki/冂']},
#  {'char': '冒',
#   'details': 'risk -- hat -- Pictograph of a hat over an eye. Based on the original meaning "hat". The meaning later shifted to "cover", "feign", "offend", and "risk".',
#   'references': ['https://www.dong-chinese.com/wiki/冒']},
#  {'char': '准',
#   'details': 'to allow -- water-level -- Simplified form of 準.  Phonosemantic compound. 氵 represents the meaning and 隼 represents the sound. Based on the original meaning "water-level", a tool to check the flatness of surfaces. The meaning later shifted to "accurate", "rule", and "approve".',
#   'references': ['https://www.dong-chinese.com/wiki/准']},
#  {'char': '减',
#   'details': 'decrease --  -- Phonosemantic compound. 冫 represents the meaning and 咸 represents the sound. Simplified form of 減. ',
#   'references': ['https://www.dong-chinese.com/wiki/减']},
#  {'char': '几',
#   'details': 'small table --  -- Pictograph of a small table. In simplified Chinese 几 is also used to mean "how much", while in traditional Chinese this meaning is written with a separate character 幾.',
#   'references': ['https://www.dong-chinese.com/wiki/几']},
#  {'char': '兼',
#   'details': 'double --  -- Depicts a hand (又) holding two stalks of grain (禾).',
#   'references': ['https://www.dong-chinese.com/wiki/兼']},
#  {'char': '内',
#   'details': 'inside --  -- Depicts a  person (人) inside a building (冂).',
#   'references': ['https://www.dong-chinese.com/wiki/内']},
#  {'char': '冕',
#   'details': 'crown --  -- Phonosemantic compound. 冃 represents the meaning and 免 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/冕']},
#  {'char': '凈',
#   'details': 'clean --  -- Phonosemantic compound. 冫 represents the meaning and 爭 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/凈']},
#  {'char': '典',
#   'details': 'document, work of scholarship --  -- Depicts a book (冊) on a table (丌).',
#   'references': ['https://www.dong-chinese.com/wiki/典']},
#  {'char': '写',
#   'details': 'write -- relocate -- Phonosemantic compound. 宀 represents the meaning and 舄 represents the sound. Based on the original meaning "relocate". The meaning later shifted to "copy" and "write". The simplified character 写 was adapted from the cursive form of the traditional character 寫.',
#   'references': ['https://www.dong-chinese.com/wiki/写']},
#  {'char': '冫',
#   'details': 'ice --  -- 冫 is a component form of 冰. Depicts chunks of ice.',
#   'references': ['https://www.dong-chinese.com/wiki/冫']},
#  {'char': '册',
#   'details': 'book --  -- Simplified form of 冊.  Pictograph of strips of bamboo strung together. In ancient China writing was done on bamboo strips.',
#   'references': ['https://www.dong-chinese.com/wiki/册']},
#  {'char': '冓',
#   'details': 'a secluded place -- meet unexpectedly -- Depicts two fish facing each other. Based on the original meaning "meet unexpectedly", now written as 遘.',
#   'references': ['https://www.dong-chinese.com/wiki/冓']},
#  {'char': '冡',
#   'details': 'to cover --  -- Depicts a hat (冃) and tiger skin (虎), conveying the meaning "cover" by soldiers who fought covered in tiger skins. The 虎 (tiger) component was later rewritten as 豕 (pig).',
#   'references': ['https://www.dong-chinese.com/wiki/冡']},
#  {'char': '净',
#   'details': 'clean --  -- Phonosemantic compound. 冫 represents the meaning and 争 represents the sound. Simplified form of 淨. ',
#   'references': ['https://www.dong-chinese.com/wiki/净']},
#  {'char': '具',
#   'details': 'tool --  -- Depicts two hands (廾) handling a cooking pot (鼎).',
#   'references': ['https://www.dong-chinese.com/wiki/具']},
#  {'char': '冘',
#   'details': 'to move on --  -- Pictograph of a person carrying a burden on their shoulder.',
#   'references': ['https://www.dong-chinese.com/wiki/冘']},
#  {'char': '冲',
#   'details': 'flush, wash away --  -- Phonosemantic compound. 冫 represents the meaning and 中 represents the sound. Simplified form of 沖 and 衝. ',
#   'references': ['https://www.dong-chinese.com/wiki/冲']},
#  {'char': '养',
#   'details': 'raise --  -- Simplified form of 養.  Phonosemantic compound. 食 represents the meaning and 羊 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/养']},
#  {'char': '冉',
#   'details': 'drooping --  -- Depicts two strands of hair drooping.',
#   'references': ['https://www.dong-chinese.com/wiki/冉']},
#  {'char': '冬',
#   'details': 'winter -- tip, extremity -- Depicts a rope with knots at both ends. Based on the original meaning "tip, extremity", now written as 終. The meaning later shifted to "winter" (the final season of the year).',
#   'references': ['https://www.dong-chinese.com/wiki/冬']},
#  {'char': '凡',
#   'details': 'all -- tray -- Depicts a wide, flat, object, such as a tray or plate. The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/凡']},
#  {'char': '农',
#   'details': 'agriculture, farming --  -- Simplified form of 農.  Depicts using a farming tool (辰) in a field (田).',
#   'references': ['https://www.dong-chinese.com/wiki/农']},
#  {'char': '冰',
#   'details': 'ice --  -- Depicts chunks (冫) of frozen water (水).',
#   'references': ['https://www.dong-chinese.com/wiki/冰']},
#  {'char': '况',
#   'details': 'condition -- cold water -- Simplified form of 況.  Phonosemantic compound. 冫 represents the meaning and 兄 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/况']},
#  {'char': '凉',
#   'details': 'cool -- light alcohol, dilute wine -- Phonosemantic compound. 冫 is a simplification of 氵 (water), based on the original meaning "light alcohol, dilute wine". 京 represents the sound. Simplified form of 涼. ',
#   'references': ['https://www.dong-chinese.com/wiki/凉']},
#  {'char': '军',
#   'details': 'army --  -- Simplified form of 軍. Phonosemantic compound. 勻 represents the sound and 車 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/军']},
#  {'char': '决',
#   'details': 'decide --  -- Simplified form of 決.  Phonosemantic compound. 氵 represents the meaning and 夬 represents the sound. Based on the original meaning "burst open". The meaning later shifted to "clear", "cut off", "decide" and "judge".',
#   'references': ['https://www.dong-chinese.com/wiki/决']},
#  {'char': '冷',
#   'details': 'cold --  -- Phonosemantic compound. 冫 represents the meaning and 令 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/冷']},
#  {'char': '其',
#   'details': 'its, his, (3p possessive) -- basket -- Pictograph of a basket, now written as 箕. The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/其']},
#  {'char': '冃',
#   'details': 'cap --  -- Depicts a hat. Original form of 帽.',
#   'references': ['https://www.dong-chinese.com/wiki/冃']},
#  {'char': '再',
#   'details': 'again --  -- Origin unclear. The 二 (two) component hints at the meaning, conveying "second" or "again". The other component seems to depict a fish, similar to 冓, but its purpose is unclear.',
#   'references': ['https://www.dong-chinese.com/wiki/再']},
#  {'char': '冏',
#   'details': 'bright window --  -- Variant of 囧. Pictograph of a window.',
#   'references': ['https://www.dong-chinese.com/wiki/冏']},
#  {'char': '冐',
#   'details': 'risk --  -- Variant of 冒.',
#   'references': ['https://www.dong-chinese.com/wiki/冐']},
#  {'char': '冎',
#   'details': 'bone --  -- Pictograph of bones. Original form of 骨 (bone).',
#   'references': ['https://www.dong-chinese.com/wiki/冎']},
#  {'char': '冄',
#   'details': 'drooping --  -- 冄 is a variant form of 冉, which depicts two strands of hair drooping.',
#   'references': ['https://www.dong-chinese.com/wiki/冄']},
#  {'char': '冈',
#   'details': 'ridge or crest of hill --  -- Simplified form of 岡.  Phonosemantic compound. 山 represents the meaning and 网 represents the sound.  The traditional component 山 was removed for simplification.',
#   'references': ['https://www.dong-chinese.com/wiki/冈']},
#  {'char': '冊',
#   'details': 'book --  -- Pictograph of strips of bamboo strung together. In ancient China writing was done on bamboo strips.',
#   'references': ['https://www.dong-chinese.com/wiki/冊']},
#  {'char': '冖',
#   'details': 'cover --  -- 冖 is a component form of 宀. ',
#   'references': ['https://www.dong-chinese.com/wiki/冖']},
#  {'char': '冠',
#   'details': 'cap --  -- Pictograph of a person (元) wearing a hat (冃). 元 also provides the sound. The 寸 (hand) component was added later to indicate the hand holding the hat on the head.',
#   'references': ['https://www.dong-chinese.com/wiki/冠']},
#  {'char': '刘',
#   'details': 'surname -- type of battle axe -- Simplified form of 劉. Phonosemantic compound. 卯 represents the sound and 金 and 刂 represent the meaning. Based on the original meaning "battle-axe". The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/刘']},
#  {'char': '凵',
#   'details': 'enclosure --  -- Pictograph of a cave or enclosure.',
#   'references': ['https://www.dong-chinese.com/wiki/凵']},
#  {'char': '别',
#   'details': 'separate --  -- Simplified form of 別.  Depicts a knife (刂) cutting meat off of a bone (另).',
#   'references': ['https://www.dong-chinese.com/wiki/别']},
#  {'char': '凯',
#   'details': 'victorious --  -- Phonosemantic compound. 岂 represents the meaning and 几 represents the sound. Simplified form of 凱.',
#   'references': ['https://www.dong-chinese.com/wiki/凯']},
#  {'char': '划',
#   'details': 'row, paddle --  -- Phonosemantic compound. 刂 represents the meaning and 戈 represents the sound. In simplified Chinese 划 is also used to mean "cut, delimit, draw", while in traditional Chinese this meaning is written with a separate character 劃.',
#   'references': ['https://www.dong-chinese.com/wiki/划']},
#  {'char': '判',
#   'details': 'judge -- cut open -- Phonosemantic compound. 刂 represents the meaning and 半 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/判']},
#  {'char': '创',
#   'details': 'begin, establish -- wound, injury -- Phonosemantic compound. 刂 represents the meaning and 仓 represents the sound. Simplified form of 創. Based on the original meaning "wound, injury". The meaning "begin, establish" is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/创']},
#  {'char': '別',
#   'details': 'separate --  -- Depicts a knife (刂) cutting meat off of a bone （冎）.',
#   'references': ['https://www.dong-chinese.com/wiki/別']},
#  {'char': '击',
#   'details': 'strike --  -- Simplified form of 擊.  Based on the cursive form of the phonetic component 毄.',
#   'references': ['https://www.dong-chinese.com/wiki/击']},
#  {'char': '刀',
#   'details': 'knife --  -- Pictograph of a knife.',
#   'references': ['https://www.dong-chinese.com/wiki/刀']},
#  {'char': '切',
#   'details': 'cut --  -- Phonosemantic compound. 刀 represents the meaning and 七 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/切']},
#  {'char': '初',
#   'details': 'beginning --  -- Depicts cutting out fabric (衤) with a knife (刀), the first step in making clothes.',
#   'references': ['https://www.dong-chinese.com/wiki/初']},
#  {'char': '凶',
#   'details': 'vicious, fierce --  -- Pictograph of a trap in the ground.',
#   'references': ['https://www.dong-chinese.com/wiki/凶']},
#  {'char': '则',
#   'details': 'rule -- law -- Simplified form of 則.  Depicts carving inscriptions on bronzeware (鼎) with a knife (刂). Based on the original meaning "law". In ancient China, some legal writings were inscribed on bronzeware.',
#   'references': ['https://www.dong-chinese.com/wiki/则']},
#  {'char': '刎',
#   'details': 'cut throat --  -- Phonosemantic compound. 刂 represents the meaning and 勿 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/刎']},
#  {'char': '刖',
#   'details': "cutting off feet as form of punishment --  -- Originally a pictograph of a saw cutting off a person's foot. Later the character was changed to a phonosemantic compound. 刂 represents the meaning and 月 represents the sound.",
#   'references': ['https://www.dong-chinese.com/wiki/刖']},
#  {'char': '函',
#   'details': 'envelop, case -- quiver, arrow case  -- Pictograph of an arrow inside a quiver. Based on the original meaning "quiver, arrow case". The meaning later shifted to "case", "box", "envelop" and "letter".',
#   'references': ['https://www.dong-chinese.com/wiki/函']},
#  {'char': '刑',
#   'details': 'punishment --  -- Phonosemantic compound. 刂 represents the meaning and 井 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/刑']},
#  {'char': '利',
#   'details': 'benefit --  -- Depicts harvesting grain (禾) with a blade (刂). Harvest was the main source of profit in agricultural societies.',
#   'references': ['https://www.dong-chinese.com/wiki/利']},
#  {'char': '凱',
#   'details': 'victorious --  -- Phonosemantic compound. 豈 represents the meaning and 几 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/凱']},
#  {'char': '刂',
#   'details': 'knife --  -- 刂 is a component form of 刀, which depicts a knife. ',
#   'references': ['https://www.dong-chinese.com/wiki/刂']},
#  {'char': '分',
#   'details': 'divide --  -- Depicts a knife ( 刀 ) being used to cut two things apart (八).',
#   'references': ['https://www.dong-chinese.com/wiki/分']},
#  {'char': '刍',
#   'details': 'mow, cut grass --  -- Simplified form of 芻. Pictograph of a hand picking off blades of grass.',
#   'references': ['https://www.dong-chinese.com/wiki/刍']},
#  {'char': '列',
#   'details': 'arrange -- break apart -- Phonosemantic compound. 刂 represents the meaning and 歹 represents the sound. Based on the original meaning "break apart". The meaning later shifted to "arrange in order" and "list".',
#   'references': ['https://www.dong-chinese.com/wiki/列']},
#  {'char': '刚',
#   'details': 'hard --  -- Simplified form of 剛.  Phonosemantic compound. 刂 represents the meaning and 岡 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/刚']},
#  {'char': '出',
#   'details': 'go out --  -- Pictograph of a foot (止) exiting a cave (凵).',
#   'references': ['https://www.dong-chinese.com/wiki/出']},
#  {'char': '刃',
#   'details': 'knife edge --  -- Pictograph of a knife. Similar to 刀 (knife), with an added dot marking where the blade is.',
#   'references': ['https://www.dong-chinese.com/wiki/刃']},
#  {'char': '前',
#   'details': 'in front -- cut -- Phonosemantic compound. 歬 represents the sound, and 刂 represents the meaning. Based on the original meaning "cut", now written as 剪. The current meaning "in front" is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/前']},
#  {'char': '刮',
#   'details': 'to scrape, shave --  -- Phonosemantic compound. 刂 represents the meaning and 𠯑 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/刮']},
#  {'char': '化',
#   'details': 'change --  -- Pictograph of a right-side up person and an upside-down person, depicting the meaning "turn around" or "transform".',
#   'references': ['https://www.dong-chinese.com/wiki/化']},
#  {'char': '卖',
#   'details': 'sell --  -- Phonosemantic compound. 出 represents the meaning and 买 represents the sound. Simplified form of 賣. ',
#   'references': ['https://www.dong-chinese.com/wiki/卖']},
#  {'char': '动',
#   'details': 'move --  -- Simplified form of 動.  Phonosemantic compound. 力 represents the meaning. The sound component 重 was simplified to 云.',
#   'references': ['https://www.dong-chinese.com/wiki/动']},
#  {'char': '助',
#   'details': 'help --  -- Phonosemantic compound. 力 represents the meaning and 且 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/助']},
#  {'char': '匃',
#   'details': 'beggar -- cut -- Variant form of 丐. Depicts the blade of a knife. Similar in origin to 亡 and 方. Based on the original meaning "cut". The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/匃']},
#  {'char': '医',
#   'details': 'medicine -- quiver -- Originally depicted a quiver, a container for arrows. Later repurposed to mean "medicine" as a simplified form of the traditional character 醫.',
#   'references': ['https://www.dong-chinese.com/wiki/医']},
#  {'char': '區',
#   'details': 'area --  -- Depicts a group of things (品) in an enclosed area.',
#   'references': ['https://www.dong-chinese.com/wiki/區']},
#  {'char': '午',
#   'details': 'noon --  -- Pictograph of a pestle used for pounding rice, now written as 杵. The current meaning "noon" is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/午']},
#  {'char': '华',
#   'details': 'magnificent --  -- Simplified form of 華.  化 is used here to represent the sound. The bottom component is a remnant from the traditional character 華.',
#   'references': ['https://www.dong-chinese.com/wiki/华']},
#  {'char': '单',
#   'details': 'single --  -- Simplified form of 單.  Pictograph of a hunting or military trap constructed from two rocks and a net. The current meaning "single" is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/单']},
#  {'char': '到',
#   'details': 'go to --  -- Phonosemantic compound. 至 represents the meaning and 刂 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/到']},
#  {'char': '劍',
#   'details': 'sword --  -- Phonosemantic compound. 刂 represents the meaning and 僉 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/劍']},
#  {'char': '劦',
#   'details': 'cooperate, combined labor --  -- Triple of 力 (strength). Depicts uniting in common effort.',
#   'references': ['https://www.dong-chinese.com/wiki/劦']},
#  {'char': '務',
#   'details': 'business --  -- Phonosemantic compound. 矛 represents the sound, while 攵 and 力 both represent the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/務']},
#  {'char': '匀',
#   'details': 'equal --  -- Simplified form of 勻.  Phonosemantic compound. 云 represents the sound and 吕 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/匀']},
#  {'char': '协',
#   'details': 'cooperate --  -- Simplified form of 協. Phonosemantic compound. 十 represents the sound and 劦 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/协']},
#  {'char': '卒',
#   'details': 'soldier, to finish -- to finish sewing clothes -- Depicts clothing (衣) with intersecting lines indicating that the clothing is done being sewed. Based on the original meaning, "to finish sewing clothes". The meaning later shifted to "to finish" and "to die" while it\'s other meaning "soldier" is a phoentic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/卒']},
#  {'char': '剋',
#   'details': 'to beat --  -- Phonosemantic compound. 克 represents the sound and 刂 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/剋']},
#  {'char': '副',
#   'details': 'assist --  -- Phonosemantic compound. 刂 represents the meaning and 畐 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/副']},
#  {'char': '加',
#   'details': 'add --  -- Depicts making loud noises with the mouth (口) to add power (力) during manual labor.',
#   'references': ['https://www.dong-chinese.com/wiki/加']},
#  {'char': '努',
#   'details': 'to exert --  -- Phonosemantic compound. 力 represents the meaning and 奴 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/努']},
#  {'char': '勢',
#   'details': 'power --  -- Phonosemantic compound. 力 represents the meaning and 埶 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/勢']},
#  {'char': '十',
#   'details': 'ten --  -- A single vertical line, representing one set of ten. Analagous to the archaic characters 廿 (twenty) and 卅 (thirty). Possibly originally a picture of a needle, now written as 針.',
#   'references': ['https://www.dong-chinese.com/wiki/十']},
#  {'char': '卓',
#   'details': 'profound -- tall -- Pictograph of a person standing erect with something above the head, based on the original meaning "tall". The meaning later shifted to "outstanding" and "profound".',
#   'references': ['https://www.dong-chinese.com/wiki/卓']},
#  {'char': '協',
#   'details': 'cooperate --  -- Phonosemantic compound. 劦 represents the meaning and 十 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/協']},
#  {'char': '博',
#   'details': 'plentiful, gamble -- fight -- Phonosemantic compound. 盾 represents the meaning and 尃 represents the sound. Based on the original meaning "fight", which later shifted to "win", "plentiful", and "gamble".',
#   'references': ['https://www.dong-chinese.com/wiki/博']},
#  {'char': '占',
#   'details': 'divine --  -- In ancient China fortune-tellers analyzed cracks (卜) and holes (口) in shells and bones for the purpose of divination.',
#   'references': ['https://www.dong-chinese.com/wiki/占']},
#  {'char': '匕',
#   'details': 'spoon --  -- Originally from two different ancient characters, one depicting a spoon and one depicting an upside-down person. 匕 can appear as a component in other characters based on either meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/匕']},
#  {'char': '匱',
#   'details': 'empty, lacking -- box -- Phonosemantic compound. 匚 represents the meaning and 貴 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/匱']},
#  {'char': '千',
#   'details': 'thousand --  -- Phonosemantic compound. 一 represents the meaning and 亻 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/千']},
#  {'char': '卑',
#   'details': 'humble, inferior --  -- Pictograph of a hand holding a tool used by servants.',
#   'references': ['https://www.dong-chinese.com/wiki/卑']},
#  {'char': '刻',
#   'details': 'carve --  -- Phonosemantic compound. 刂 represents the meaning and 亥 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/刻']},
#  {'char': '則',
#   'details': 'rule -- law -- Depicts carving inscriptions on bronzeware (鼎) with a knife (刂). Based on the original meaning "law". In ancient China, some legal writings were inscribed on bronzeware.',
#   'references': ['https://www.dong-chinese.com/wiki/則']},
#  {'char': '勿',
#   'details': 'must not -- cut throat -- Depicts a knife (刀) cutting with drops of blood coming out, based on the original meaning "cut throat", now written as 刎. The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/勿']},
#  {'char': '匈',
#   'details': 'breast --  -- Phonosemantic compound. 勹 represents the meaning and 凶 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/匈']},
#  {'char': '剑',
#   'details': 'sword --  -- Phonosemantic compound. 刂 represents the meaning and 佥 represents the sound. Simplified form of 劍. ',
#   'references': ['https://www.dong-chinese.com/wiki/剑']},
#  {'char': '剧',
#   'details': 'severe, dramatic, theatrical play --  -- Phonosemantic compound. 刂 represents the meaning and 居 represents the sound. Simplified form of 劇. ',
#   'references': ['https://www.dong-chinese.com/wiki/剧']},
#  {'char': '功',
#   'details': 'achievement --  -- Phonosemantic compound. 力 represents the meaning and 工 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/功']},
#  {'char': '劲',
#   'details': 'strong --  -- Phonosemantic compound. 力 represents the meaning and 𢀖 represents the sound. Simplified form of 勁. ',
#   'references': ['https://www.dong-chinese.com/wiki/劲']},
#  {'char': '劳',
#   'details': 'labor --  -- Simplified form of 勞.  Depicts the hard work of sewing clothes (衣) with only firelight (炏). Later the 力 (strength, power) component was added.',
#   'references': ['https://www.dong-chinese.com/wiki/劳']},
#  {'char': '勁',
#   'details': 'strong --  -- Phonosemantic compound. 力 represents the meaning and 巠 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/勁']},
#  {'char': '勝',
#   'details': 'victory --  -- Phonosemantic compound. 力 represents the meaning and 朕 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/勝']},
#  {'char': '包',
#   'details': 'wrap --  -- Pictograph of an unborn baby contained inside its mother.',
#   'references': ['https://www.dong-chinese.com/wiki/包']},
#  {'char': '匙',
#   'details': 'spoon --  -- Phonosemantic compound. 匕 represents the meaning and 是 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/匙']},
#  {'char': '卅',
#   'details': 'thirty --  -- Three vertical lines, representing three sets of ten (十).',
#   'references': ['https://www.dong-chinese.com/wiki/卅']},
#  {'char': '刺',
#   'details': 'stab --  -- Phonosemantic compound. 刂 represents the meaning and 朿 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/刺']},
#  {'char': '劇',
#   'details': 'severe, dramatic, theatrical play --  -- Phonosemantic compound. 刂 represents the meaning and 豦 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/劇']},
#  {'char': '务',
#   'details': 'business --  -- Simplified form of 務.  Phonosemantic compound. 矛 represents the sound, while 攵 and 力 both represent the meaning. The traditional component 矛 was removed for simplification.',
#   'references': ['https://www.dong-chinese.com/wiki/务']},
#  {'char': '勻',
#   'details': 'equal --  -- Phonosemantic compound. 云 represents the sound and 吕 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/勻']},
#  {'char': '勾',
#   'details': 'hook --  -- 勾 originated as a variant of 句. 口 represents the sound and 丩 represents the meaning and the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/勾']},
#  {'char': '匍',
#   'details': 'crawl --  -- Phonosemantic compound. 勹 represents the meaning and 甫 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/匍']},
#  {'char': '匮',
#   'details': 'empty, lacking --  -- Phonosemantic compound. 匚 represents the meaning and 贵 represents the sound. Simplified from 匱.',
#   'references': ['https://www.dong-chinese.com/wiki/匮']},
#  {'char': '势',
#   'details': 'power --  -- Phonosemantic compound. 力 represents the meaning and 执 represents the sound. Simplified form of 勢. ',
#   'references': ['https://www.dong-chinese.com/wiki/势']},
#  {'char': '区',
#   'details': 'area --  -- Simplified form of 區.  Depicts a group of things (品) in an enclosed area.',
#   'references': ['https://www.dong-chinese.com/wiki/区']},
#  {'char': '卡',
#   'details': 'stuck --  -- Origin unclear, but typically explained as being stuck between something above (上) and something below (下). The uses of 卡 to mean "card" or "calorie" are foreign phonetic loans.',
#   'references': ['https://www.dong-chinese.com/wiki/卡']},
#  {'char': '励',
#   'details': 'strive --  -- Phonosemantic compound. 力 represents the meaning and 厉 represents the sound. Simplified form of 勵.',
#   'references': ['https://www.dong-chinese.com/wiki/励']},
#  {'char': '勃',
# ...
#  {'char': '型',
#   'details': 'pattern, mold --  -- Phonosemantic compound. 土 represents the meaning and 刑 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/型']},
#  {'char': '培',
#   'details': 'bank up with dirt, cultivate --  -- Phonosemantic compound. 土 represents the meaning and 咅 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/培']},
#  {'char': '圾',
#   'details': 'garbage --  -- Phonosemantic compound. 土 represents the meaning and 及 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/圾']},
#  {'char': '垔',
#   'details': 'dam up, block, restrain --  -- Origin unclear.',
#   'references': ['https://www.dong-chinese.com/wiki/垔']},
#  {'char': '坪',
#   'details': 'level ground --  -- Phonosemantic compound. 土 represents the meaning and 平 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/坪']},
#  {'char': '執',
#   'details': 'hold in hand -- seize -- Pictograph of a person with hands (丮) bound by shackles (㚔). Based on the original meaning "seize". The meaning later shifted to "wield power", "carry out", and "hold".',
#   'references': ['https://www.dong-chinese.com/wiki/執']},
#  {'char': '場',
#   'details': 'open space --  -- Phonosemantic compound. 土 represents the meaning and 昜 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/場']},
#  {'char': '坍',
#   'details': 'collapse --  -- Phonosemantic compound. 土 represents the meaning and 丹 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/坍']},
#  {'char': '堡',
#   'details': 'fortress --  -- Phonosemantic compound. 土 represents the meaning and 保 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/堡']},
#  {'char': '堯',
#   'details': 'legendary ancient emperor-sage -- tall; lofty -- Depicts a mound of dirt (土) on top of a platform (兀), representing the original meaning "tall; lofty", later used to describe the legendary Emperor Yao.',
#   'references': ['https://www.dong-chinese.com/wiki/堯']},
#  {'char': '埜',
#   'details': 'open country --  -- Variant of 野.',
#   'references': ['https://www.dong-chinese.com/wiki/埜']},
#  {'char': '堵',
#   'details': 'block up --  -- Phonosemantic compound. 土 represents the meaning and 者 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/堵']},
#  {'char': '块',
#   'details': 'piece --  -- Simplified form of 塊.  Phonosemantic compound. 土 represents the meaning and 夬 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/块']},
#  {'char': '報',
#   'details': 'report -- punish -- Depicts a person being subdued (𠬝) by shackles (㚔). Based on the original meaning "punish". The meaning later shifted to "revenge", "recompense", "report", and "announce".',
#   'references': ['https://www.dong-chinese.com/wiki/報']},
#  {'char': '城',
#   'details': 'city --  -- Phonosemantic compound. 土 represents the meaning and 成 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/城']},
#  {'char': '址',
#   'details': 'site, location --  -- Phonosemantic compound. 土 represents the meaning and 止 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/址']},
#  {'char': '坚',
#   'details': 'firm, solid --  -- Simplified form of 堅.  Phonosemantic compound. 土 represents the meaning and 臤 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/坚']},
#  {'char': '埰',
#   'details': 'fief --  -- Phonosemantic compound. 土 represents the meaning and 采 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/埰']},
#  {'char': '堆',
#   'details': 'heap, pile --  -- Phonosemantic compound. 土 represents the meaning and 隹 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/堆']},
#  {'char': '坿',
#   'details': 'mound --  -- Variant of 附.',
#   'references': ['https://www.dong-chinese.com/wiki/坿']},
#  {'char': '均',
#   'details': 'equal --  -- Phonosemantic compound. 土 represents the meaning and 勻 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/均']},
#  {'char': '埶',
#   'details': 'art, skill -- to plant -- Depicts a person with two hands outstretched (丮) planting something in the ground (土).',
#   'references': ['https://www.dong-chinese.com/wiki/埶']},
#  {'char': '坐',
#   'details': 'sit --  -- Depicts two people (人) sitting on the ground (土).',
#   'references': ['https://www.dong-chinese.com/wiki/坐']},
#  {'char': '坦',
#   'details': 'flat --  -- Phonosemantic compound. 土 represents the meaning and 旦 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/坦']},
#  {'char': '垂',
#   'details': 'droop -- borderland -- Phonosemantic compound. 土 represents the meaning and 𠂹 represents the sound. Based on the original meaning "borderland", now written as 陲. The current meaning is a phonetic loan.',
#   'references': ['https://www.dong-chinese.com/wiki/垂']},
#  {'char': '域',
#   'details': 'district --  -- Phonosemantic compound. 土 represents the meaning and 或 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/域']},
#  {'char': '堅',
#   'details': 'firm, solid --  -- Phonosemantic compound. 土 represents the meaning and 臤 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/堅']},
#  {'char': '堇',
#   'details': 'clay -- burn -- Pictograph of a person facing upwards with their mouth open over a fire. Based on the original meaning "burn". The meaning later shifted to "bake", "dry out", and "clay".',
#   'references': ['https://www.dong-chinese.com/wiki/堇']},
#  {'char': '恭',
#   'details': 'respectful --  -- Phonosemantic compound. ⺗ represents the meaning and 共 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/恭']},
#  {'char': '恠',
#   'details': 'strange --  -- Variant of 怪 with 在 used as the phonetic component.',
#   'references': ['https://www.dong-chinese.com/wiki/恠']},
#  {'char': '恩',
#   'details': 'kindness --  -- Phonosemantic compound. 心 represents the meaning and 因 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/恩']},
#  {'char': '恶',
#   'details': 'evil --  -- Phonosemantic compound. 心 represents the meaning and 亚 represents the sound. Simplified form of 惡. ',
#   'references': ['https://www.dong-chinese.com/wiki/恶']},
#  {'char': '恢',
#   'details': 'restore --  -- Phonosemantic compound. 忄 represents the meaning and 灰 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/恢']},
#  {'char': '恐',
#   'details': 'fear --  -- Phonosemantic compound. 心 represents the meaning and 巩 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/恐']},
#  {'char': '息',
#   'details': 'rest -- breathe -- Depicts a breath of air going into the nose (自). The lines representing breath were later reanalyzed as 心 (heart).',
#   'references': ['https://www.dong-chinese.com/wiki/息']},
#  {'char': '恼',
#   'details': 'get angry --  -- Phonosemantic compound. 忄 represents the meaning and 𡿺 represents the sound. Simplified form of 惱.',
#   'references': ['https://www.dong-chinese.com/wiki/恼']},
#  {'char': '恋',
#   'details': 'love --  -- Simplified form of 戀. Phonosemantic compound. 心 represents the meaning and 䜌 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/恋']},
#  {'char': '恨',
#   'details': 'hatred --  -- Phonosemantic compound. 忄 represents the meaning and 艮 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/恨']},
#  {'char': '您',
#   'details': "honorific for 'you' --  -- Phonosemantic compound. 心 represents the meaning and 你 represents the sound. ",
#   'references': ['https://www.dong-chinese.com/wiki/您']},
#  {'char': '悉',
#   'details': 'thorough and detailed --  -- Alludes to knowing (心) the distinctions (釆) between things thoroughly.',
#   'references': ['https://www.dong-chinese.com/wiki/悉']},
#  {'char': '悤',
#   'details': 'agitated --  -- Phonosemantic compound. 心 represents the meaning and 囱 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/悤']},
#  {'char': '悳',
#   'details': 'ethics --  -- Variant form of 惪',
#   'references': ['https://www.dong-chinese.com/wiki/悳']},
#  {'char': '悔',
#   'details': 'repent --  -- Phonosemantic compound. 忄 represents the meaning and 每 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/悔']},
#  {'char': '悲',
#   'details': 'sorrow --  -- Phonosemantic compound. 心 represents the meaning and 非 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/悲']},
#  {'char': '惠',
#   'details': 'favor -- benevolence -- Phonosemantic compound. 心 represents the meaning and 叀 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/惠']},
#  {'char': '愛',
#   'details': 'love --  -- Originally a phonosemantic compound, with 旡 representing the sound and 心 (heart) representing the meaning. Later the 夂 component was added.',
#   'references': ['https://www.dong-chinese.com/wiki/愛']},
#  {'char': '愿',
#   'details': 'sincere --  -- Phonosemantic compound. 心 represents the meaning and 原 represents the sound. In simplified Chinese 愿 is also used to mean "hope; wish", while in traditional Chinese this meaning is written with a separate character 願.',
#   'references': ['https://www.dong-chinese.com/wiki/愿']},
#  {'char': '情',
#   'details': 'feeling --  -- Phonosemantic compound. 忄 represents the meaning and 青 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/情']},
#  {'char': '惪',
#   'details': 'virtue --  -- Virtuous people have a straight (直) heart (心). 直 also represents the sound. Original form of 德.',
#   'references': ['https://www.dong-chinese.com/wiki/惪']},
#  {'char': '愉',
#   'details': 'pleasant --  -- Phonosemantic compound. 忄 represents the meaning and 俞 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/愉']},
#  {'char': '惊',
#   'details': 'startle, frighten --  -- Phonosemantic compound. 忄 represents the meaning and 京 represents the sound. Simplified form of 驚. ',
#   'references': ['https://www.dong-chinese.com/wiki/惊']},
#  {'char': '愾',
#   'details': 'anger --  -- Phonosemantic compound. 忄 represents the meaning and 氣 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/愾']},
#  {'char': '惜',
#   'details': 'pity --  -- Phonosemantic compound. 忄 represents the meaning and 昔 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/惜']},
#  {'char': '惷',
#   'details': 'wriggle --  -- Variant of 蠢.',
#   'references': ['https://www.dong-chinese.com/wiki/惷']},
#  {'char': '愽',
#   'details': 'gamble --  -- Phonosemantic compound. 忄 represents the meaning and 尃 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/愽']},
#  {'char': '惡',
#   'details': 'evil --  -- Phonosemantic compound. 心 represents the meaning and 亞 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/惡']},
#  {'char': '想',
#   'details': 'think --  -- Phonosemantic compound. 心 represents the meaning and 相 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/想']},
#  {'char': '愬',
#   'details': 'accuse --  -- Variant of 訴. Phonosemantic compound. 朔 represents the sound and 心 represents the meaning.',
#   'references': ['https://www.dong-chinese.com/wiki/愬']},
#  {'char': '意',
#   'details': 'thought --  -- Thought (意) is the sound (音) that comes from the mind (心). (Oversimplified for brevity. The 音 component in this character has a complicated history.)',
#   'references': ['https://www.dong-chinese.com/wiki/意']},
#  {'char': '感',
#   'details': 'feel --  -- Phonosemantic compound. 心 represents the meaning and 咸 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/感']},
#  {'char': '惯',
#   'details': 'habit --  -- Phonosemantic compound. 忄 represents the meaning and 贯 represents the sound. Simplified form of 慣. ',
#   'references': ['https://www.dong-chinese.com/wiki/惯']},
#  {'char': '惱',
#   'details': 'get angry --  -- Phonosemantic compound. 忄 represents the meaning and 𡿺 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/惱']},
#  {'char': '慣',
#   'details': 'habit --  -- Phonosemantic compound. 忄 represents the meaning and 貫 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/慣']},
#  {'char': '態',
#   'details': 'manner --  -- Phonosemantic compound. 心 represents the meaning and 能 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/態']},
#  {'char': '憶',
#   'details': 'remember --  -- Phonosemantic compound. 忄 represents the meaning and 意 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/憶']},
#  {'char': '慢',
#   'details': 'slow(ly) --  -- Phonosemantic compound. 忄 represents the meaning and 曼 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/慢']},
#  {'char': '慕',
#   'details': 'admire, desire --  -- Phonosemantic compound. ⺗ represents the meaning and 莫 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/慕']},
#  {'char': '慮',
#   'details': 'be concerned --  -- Phonosemantic compound. 思 represents the meaning and 虍 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/慮']},
#  {'char': '憐',
#   'details': 'pity --  -- Phonosemantic compound. 忄 represents the meaning and 粦 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/憐']},
#  {'char': '慶',
#   'details': 'celebrate -- good -- Depicts a legendary animal considered to be good (廌) and a heart (心).',
#   'references': ['https://www.dong-chinese.com/wiki/慶']},
#  {'char': '憂',
#   'details': 'sad --  -- Phonosemantic compound. 心 represents the meaning and 夔 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/憂']},
#  {'char': '懂',
#   'details': 'understand --  -- Phonosemantic compound. 忄 represents the meaning and 董 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/懂']},
#  {'char': '懷',
#   'details': 'bosom, embrace --  -- Phonosemantic compound. 忄 represents the meaning and 褱 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/懷']},
#  {'char': '應',
#   'details': 'should --  -- Phonosemantic compound. 心 represents the meaning and 䧹 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/應']},
#  {'char': '懒',
#   'details': 'lazy --  -- Phonosemantic compound. 忄 represents the meaning and 赖 represents the sound. Simplified form of 懶. ',
#   'references': ['https://www.dong-chinese.com/wiki/懒']},
#  {'char': '懶',
#   'details': 'lazy --  -- Phonosemantic compound. 忄 represents the meaning and 賴 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/懶']},
#  {'char': '懽',
#   'details': 'happy --  -- Phonosemantic compound. 忄 represents the meaning and 雚 represents the sound.',
#   'references': ['https://www.dong-chinese.com/wiki/懽']},
#  {'char': '戶',
#   'details': 'door --  -- Pictograph of a door, similar to the left half of 門.',
#   'references': ['https://www.dong-chinese.com/wiki/戶']},
#  {'char': '戏',
#   'details': 'play -- military troops outside the main group -- Simplified form of 戲. Phonosemantic compound. 戈 represents the meaning and 䖒 represents the sound. Based on the original meaning "military troops outside the main group". The meaning later shifted to "sport" and "play".',
#   'references': ['https://www.dong-chinese.com/wiki/戏']},
#  {'char': '打',
#   'details': 'strike --  -- Phonosemantic compound. 扌 represents the meaning and 丁 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/打']},
#  {'char': '战',
#   'details': 'war --  -- Phonosemantic compound. 戈 represents the meaning and 占 represents the sound. Simplified form of 戰. ',
#   'references': ['https://www.dong-chinese.com/wiki/战']},
#  {'char': '戀',
#   'details': 'to long for, love --  -- Phonosemantic compound. 心 represents the meaning and 䜌 represents the sound. ',
#   'references': ['https://www.dong-chinese.com/wiki/戀']},
#  {'char': '戱',
#   'details': 'theatrical play --  -- Variant of 戲.',
#   'references': ['https://www.dong-chinese.com/wiki/戱']},
#  ...]

# %%
# create json file
with open("dong_chinese.json", "w", encoding="utf-8") as f:
    json.dump(reduced_dict, f, ensure_ascii=False, indent=2)
